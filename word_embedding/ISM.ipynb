# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import nltk
import sklearn as sklearn
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# # Import data

# %%
# %cd /Users/Allen/Documents/NLP/dataset
import csv
if __name__ == "__main__":
    fin = open("Sentiment Analysis Dataset.csv", "r")
    fout = open("sad-clean.csv", "w")
    writer = csv.writer(fout)
    try:
        # we know the first 3 columns are consistent...
        for row in fin:
            parts = row.strip().split(",")
            out = parts[0:3] + [",".join(parts[3:])]
            writer.writerow(out)
    finally:
        fin.close()
        fout.close()
# Out:
# /Users/Allen/Documents/NLP/dataset

# %%
data = pd.read_csv("sad-clean.csv",encoding='latin-1')
data = data.rename(columns={"v1":"label", "v4":"text"})

# %%
data.head(10)
# Out:
#    ItemID  Sentiment SentimentSource  \
# 0       1          0    Sentiment140
# 1       2          0    Sentiment140
# 2       3          1    Sentiment140
# 3       4          0    Sentiment140
# 4       5          0    Sentiment140
# 5       6          0    Sentiment140
# 6       7          1    Sentiment140
# 7       8          0    Sentiment140
# 8       9          1    Sentiment140
# 9      10          1    Sentiment140
#
#                                        SentimentText
# 0                       is so sad for my APL frie...
# 1                     I missed the New Moon trail...
# 2                            omg its already 7:30 :O
# 3            .. Omgaga. Im sooo  im gunna CRy. I'...
# 4           i think mi bf is cheating on me!!!   ...
# 5                          or i just worry too much?
# 6                 Juuuuuuuuuuuuuuuuussssst Chillin!!
# 7         Sunny Again        Work Tomorrow  :-|  ...
# 8        handed in my uniform today . i miss you ...
# 9           hmmmm.... i wonder how she my number @-)

# %% [markdown]
# By examining the top 10 tweets, we realize that many words are informal, which makes it more difficult to vectorize the words

# %%
data = data.drop(["ItemID", "SentimentSource"], axis=1)
data = data.rename(columns={"Sentiment":"label", "SentimentText":"text"})

from nltk import FreqDist
FreqDist(data["label"])             #result shows that it is a balanced dataset
# Out:
# FreqDist({0: 788442, 1: 790185})

# %% [markdown]
# # Examining most frequent words

# %%
from nltk.tokenize import RegexpTokenizer 
from nltk.corpus import stopwords
tokenizer = RegexpTokenizer(r'\w+') #tokenize words while removing punctuations
from nltk.stem import WordNetLemmatizer 
lemmatizer = WordNetLemmatizer() #to combine words of same lemma

# %%
#Separate the training set to "pos" and "neg" 
pos = data.loc[data.label == 1]
neg = data.loc[data.label == 0]

# %%
posword = list(map(tokenizer.tokenize,pos.text))
negword = list(map(tokenizer.tokenize,neg.text))
#make flatten list
pos_list = [item for sublist in posword for item in sublist]
neg_list = [item for sublist in negword for item in sublist]

# %%
#change to lower case
pos_list=list(map(str.lower,pos_list))
neg_list=list(map(str.lower,neg_list))

#use Lemmatizer to combine words of same lemma
pos_list=list(map(lemmatizer.lemmatize,pos_list))
neg_list=list(map(lemmatizer.lemmatize,neg_list))

# %%
#create frequency list
posfreq=FreqDist(pos_list)
negfreq=FreqDist(neg_list)

#top 50 words
pos_topwords= posfreq.most_common(80)
neg_topwords= negfreq.most_common(80)

# %%
#remove stopwords
pos_topwords = list(filter(lambda x: not str(x[0]).isdigit() and 
                           str(x[0]) not in stopwords.words("english"), pos_topwords))
neg_topwords = list(filter(lambda x: not str(x[0]).isdigit() and 
                           str(x[0]) not in stopwords.words("english"), neg_topwords))

# %%
pos_topwords[:15]
# Out:
# [('good', 60865),
#  ('day', 54488),
#  ('love', 50255),
#  ('http', 46264),
#  ('quot', 45471),
#  ('wa', 45392),
#  ('u', 39735),
#  ('like', 38297),
#  ('get', 38031),
#  ('lol', 36000),
#  ('com', 34833),
#  ('thanks', 34607),
#  ('â', 34263),
#  ('time', 33983),
#  ('going', 30546)]

# %%
neg_topwords[:15]
# Out:
# [('wa', 59386),
#  ('day', 50092),
#  ('get', 47872),
#  ('go', 47605),
#  ('work', 45586),
#  ('like', 41367),
#  ('today', 38104),
#  ('want', 33688),
#  ('going', 33418),
#  ('got', 33031),
#  ('back', 32674),
#  ('miss', 31551),
#  ('time', 31319),
#  ('really', 31172),
#  ('im', 30988)]

# %% [markdown]
# # Training Word2vec model
# Use tweet tokenizer from NLTK library to tokenize the words and build a w2v model using Gensim library

# %%
from nltk.tokenize import TweetTokenizer
tokenizer = TweetTokenizer(strip_handles=True, reduce_len=True)

w2v_data = data["text"]
w2v_data = list(map(tokenizer.tokenize,w2v_data))

# %%
# import modules & set up logging
import gensim, logging
from gensim.models import word2vec
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
sentences = w2v_data

# train word2vec on the tweets, 100 dimensions
model = gensim.models.Word2Vec(sentences, min_count=1,size=100)
# Out:
# 2018-04-15 14:18:59,612 : INFO : collecting all words and their counts
# 2018-04-15 14:18:59,614 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-04-15 14:18:59,660 : INFO : PROGRESS: at sentence #10000, processed 151136 words, keeping 20327 word types
# 2018-04-15 14:18:59,715 : INFO : PROGRESS: at sentence #20000, processed 328341 words, keeping 32976 word types
# 2018-04-15 14:18:59,779 : INFO : PROGRESS: at sentence #30000, processed 480968 words, keeping 39844 word types
# 2018-04-15 14:18:59,876 : INFO : PROGRESS: at sentence #40000, processed 633803 words, keeping 46029 word types
# 2018-04-15 14:18:59,986 : INFO : PROGRESS: at sentence #50000, processed 783960 words, keeping 51477 word types
# 2018-04-15 14:19:00,094 : INFO : PROGRESS: at sentence #60000, processed 934190 words, keeping 56609 word types
# 2018-04-15 14:19:00,174 : INFO : PROGRESS: at sentence #70000, processed 1085720 words, keeping 61429 word types
# 2018-04-15 14:19:00,255 : INFO : PROGRESS: at sentence #80000, processed 1236644 words, keeping 65898 word types
# 2018-04-15 14:19:00,387 : INFO : PROGRESS: at sentence #90000, processed 1383972 words, keeping 70286 word types
# 2018-04-15 14:19:00,475 : INFO : PROGRESS: at sentence #100000, processed 1533879 words, keeping 74480 word types
# 2018-04-15 14:19:00,551 : INFO : PROGRESS: at sentence #110000, processed 1689354 words, keeping 78495 word types
# 2018-04-15 14:19:00,616 : INFO : PROGRESS: at sentence #120000, processed 1846950 words, keeping 82358 word types
# 2018-04-15 14:19:00,713 : INFO : PROGRESS: at sentence #130000, processed 1997684 words, keeping 86319 word types
# 2018-04-15 14:19:00,834 : INFO : PROGRESS: at sentence #140000, processed 2152397 words, keeping 90012 word types
# 2018-04-15 14:19:00,928 : INFO : PROGRESS: at sentence #150000, processed 2305595 words, keeping 93725 word types
# 2018-04-15 14:19:03,631 : INFO : PROGRESS: at sentence #440000, processed 6726679 words, keeping 179525 word types
# 2018-04-15 14:19:03,748 : INFO : PROGRESS: at sentence #450000, processed 6878400 words, keeping 182089 word types
# 2018-04-15 14:19:03,920 : INFO : PROGRESS: at sentence #460000, processed 7028056 words, keeping 184668 word types
# 2018-04-15 14:19:04,057 : INFO : PROGRESS: at sentence #470000, processed 7182212 words, keeping 187229 word types
# 2018-04-15 14:19:04,174 : INFO : PROGRESS: at sentence #480000, processed 7333300 words, keeping 189828 word types
# 2018-04-15 14:19:04,277 : INFO : PROGRESS: at sentence #490000, processed 7483522 words, keeping 192378 word types
# 2018-04-15 14:19:04,369 : INFO : PROGRESS: at sentence #500000, processed 7636122 words, keeping 194636 word types
# 2018-04-15 14:19:04,454 : INFO : PROGRESS: at sentence #510000, processed 7786365 words, keeping 197076 word types
# 2018-04-15 14:19:04,546 : INFO : PROGRESS: at sentence #520000, processed 7939830 words, keeping 200187 word types
# 2018-04-15 14:19:04,623 : INFO : PROGRESS: at sentence #530000, processed 8097320 words, keeping 202995 word types
# 2018-04-15 14:19:04,730 : INFO : PROGRESS: at sentence #540000, processed 8252238 words, keeping 206112 word types
# 2018-04-15 14:19:04,847 : INFO : PROGRESS: at sentence #550000, processed 8417731 words, keeping 210205 word types
# 2018-04-15 14:19:04,933 : INFO : PROGRESS: at sentence #560000, processed 8576883 words, keeping 213680 word types
# 2018-04-15 14:19:05,017 : INFO : PROGRESS: at sentence #570000, processed 8730577 words, keeping 216631 word types
# 2018-04-15 14:19:05,115 : INFO : PROGRESS: at sentence #580000, processed 8890623 words, keeping 220359 word types
# 2018-04-15 14:19:05,207 : INFO : PROGRESS: at sentence #590000, processed 9047597 words, keeping 223935 word types
# 2018-04-15 14:19:05,288 : INFO : PROGRESS: at sentence #600000, processed 9203463 words, keeping 227179 word types
# 2018-04-15 14:19:05,420 : INFO : PROGRESS: at sentence #610000, processed 9356916 words, keeping 230510 word types
# 2018-04-15 14:19:05,596 : INFO : PROGRESS: at sentence #620000, processed 9508899 words, keeping 234356 word types
# 2018-04-15 14:19:05,684 : INFO : PROGRESS: at sentence #630000, processed 9662199 words, keeping 237698 word types
# 2018-04-15 14:19:05,772 : INFO : PROGRESS: at sentence #640000, processed 9818691 words, keeping 241263 word types
# 2018-04-15 14:19:05,871 : INFO : PROGRESS: at sentence #650000, processed 9974251 words, keeping 244523 word types
# 2018-04-15 14:19:05,983 : INFO : PROGRESS: at sentence #660000, processed 10119064 words, keeping 247868 word types
# 2018-04-15 14:19:06,085 : INFO : PROGRESS: at sentence #670000, processed 10273997 words, keeping 251235 word types
# 2018-04-15 14:19:06,191 : INFO : PROGRESS: at sentence #680000, processed 10428128 words, keeping 254344 word types
# 2018-04-15 14:19:06,289 : INFO : PROGRESS: at sentence #690000, processed 10581478 words, keeping 257252 word types
# 2018-04-15 14:19:06,406 : INFO : PROGRESS: at sentence #700000, processed 10730952 words, keeping 260255 word types
# 2018-04-15 14:19:12,235 : INFO : PROGRESS: at sentence #1260000, processed 19421238 words, keeping 409433 word types
# 2018-04-15 14:19:12,306 : INFO : PROGRESS: at sentence #1270000, processed 19585421 words, keeping 411760 word types
# 2018-04-15 14:19:12,374 : INFO : PROGRESS: at sentence #1280000, processed 19742285 words, keeping 414131 word types
# 2018-04-15 14:19:12,431 : INFO : PROGRESS: at sentence #1290000, processed 19897567 words, keeping 416166 word types
# 2018-04-15 14:19:12,499 : INFO : PROGRESS: at sentence #1300000, processed 20051664 words, keeping 418783 word types
# 2018-04-15 14:19:12,573 : INFO : PROGRESS: at sentence #1310000, processed 20202953 words, keeping 421193 word types
# 2018-04-15 14:19:12,660 : INFO : PROGRESS: at sentence #1320000, processed 20362105 words, keeping 423614 word types
# 2018-04-15 14:19:12,725 : INFO : PROGRESS: at sentence #1330000, processed 20515802 words, keeping 425659 word types
# 2018-04-15 14:19:12,802 : INFO : PROGRESS: at sentence #1340000, processed 20675109 words, keeping 427768 word types
# 2018-04-15 14:19:12,869 : INFO : PROGRESS: at sentence #1350000, processed 20827075 words, keeping 429971 word types
# 2018-04-15 14:19:12,956 : INFO : PROGRESS: at sentence #1360000, processed 20980208 words, keeping 432124 word types
# 2018-04-15 14:19:13,050 : INFO : PROGRESS: at sentence #1370000, processed 21144158 words, keeping 434888 word types
# 2018-04-15 14:19:13,132 : INFO : PROGRESS: at sentence #1380000, processed 21299989 words, keeping 437538 word types
# 2018-04-15 14:19:13,211 : INFO : PROGRESS: at sentence #1390000, processed 21447710 words, keeping 440382 word types
# 2018-04-15 14:19:13,269 : INFO : PROGRESS: at sentence #1400000, processed 21603247 words, keeping 443054 word types
# 2018-04-15 14:19:13,344 : INFO : PROGRESS: at sentence #1410000, processed 21755796 words, keeping 445384 word types
# 2018-04-15 14:19:13,410 : INFO : PROGRESS: at sentence #1420000, processed 21914004 words, keeping 447474 word types
# 2018-04-15 14:19:13,502 : INFO : PROGRESS: at sentence #1430000, processed 22068847 words, keeping 449973 word types
# 2018-04-15 14:19:13,572 : INFO : PROGRESS: at sentence #1440000, processed 22222610 words, keeping 454397 word types
# 2018-04-15 14:19:13,653 : INFO : PROGRESS: at sentence #1450000, processed 22381182 words, keeping 456118 word types
# 2018-04-15 14:19:13,733 : INFO : PROGRESS: at sentence #1460000, processed 22544000 words, keeping 457902 word types
# 2018-04-15 14:19:13,788 : INFO : PROGRESS: at sentence #1470000, processed 22689972 words, keeping 459923 word types
# 2018-04-15 14:19:13,861 : INFO : PROGRESS: at sentence #1480000, processed 22848498 words, keeping 462009 word types
# 2018-04-15 14:19:13,934 : INFO : PROGRESS: at sentence #1490000, processed 23011128 words, keeping 464546 word types
# 2018-04-15 14:19:14,004 : INFO : PROGRESS: at sentence #1500000, processed 23161463 words, keeping 467023 word types
# 2018-04-15 14:19:14,075 : INFO : PROGRESS: at sentence #1510000, processed 23311185 words, keeping 469243 word types
# 2018-04-15 14:19:14,164 : INFO : PROGRESS: at sentence #1520000, processed 23479337 words, keeping 471678 word types
words/s, in_qsize 5, out_qsize 0
# 2018-04-15 14:21:23,695 : INFO : EPOCH 5 - PROGRESS: at 34.93% examples, 701148 words/s, in_qsize 5, out_qsize 0
# 2018-04-15 14:21:24,697 : INFO : EPOCH 5 - PROGRESS: at 38.57% examples, 699463 words/s, in_qsize 5, out_qsize 0
# 2018-04-15 14:21:25,699 : INFO : EPOCH 5 - PROGRESS: at 42.34% examples, 699568 words/s, in_qsize 6, out_qsize 0
# 2018-04-15 14:21:26,699 : INFO : EPOCH 5 - PROGRESS: at 45.97% examples, 697138 words/s, in_qsize 5, out_qsize 0
# 2018-04-15 14:21:27,720 : INFO : EPOCH 5 - PROGRESS: at 49.52% examples, 692837 words/s, in_qsize 5, out_qsize 0
# 2018-04-15 14:21:28,724 : INFO : EPOCH 5 - PROGRESS: at 53.15% examples, 690922 words/s, in_qsize 5, out_qsize 0
# 2018-04-15 14:21:29,724 : INFO : EPOCH 5 - PROGRESS: at 56.88% examples, 690823 words/s, in_qsize 5, out_qsize 0
# 2018-04-15 14:21:30,726 : INFO : EPOCH 5 - PROGRESS: at 60.82% examples, 692968 words/s, in_qsize 5, out_qsize 0
# 2018-04-15 14:21:31,736 : INFO : EPOCH 5 - PROGRESS: at 64.60% examples, 693827 words/s, in_qsize 5, out_qsize 0
# 2018-04-15 14:21:32,740 : INFO : EPOCH 5 - PROGRESS: at 68.47% examples, 695076 words/s, in_qsize 5, out_qsize 0
# 2018-04-15 14:21:33,766 : INFO : EPOCH 5 - PROGRESS: at 72.18% examples, 694378 words/s, in_qsize 5, out_qsize 0
# 2018-04-15 14:21:34,771 : INFO : EPOCH 5 - PROGRESS: at 75.80% examples, 693157 words/s, in_qsize 5, out_qsize 0
# 2018-04-15 14:21:35,781 : INFO : EPOCH 5 - PROGRESS: at 79.64% examples, 694262 words/s, in_qsize 4, out_qsize 1
# 2018-04-15 14:21:36,790 : INFO : EPOCH 5 - PROGRESS: at 83.36% examples, 694246 words/s, in_qsize 5, out_qsize 0
# 2018-04-15 14:21:37,792 : INFO : EPOCH 5 - PROGRESS: at 87.04% examples, 694108 words/s, in_qsize 5, out_qsize 0
# 2018-04-15 14:21:38,800 : INFO : EPOCH 5 - PROGRESS: at 91.00% examples, 695648 words/s, in_qsize 5, out_qsize 0
# 2018-04-15 14:21:39,804 : INFO : EPOCH 5 - PROGRESS: at 94.84% examples, 696484 words/s, in_qsize 5, out_qsize 0
# 2018-04-15 14:21:40,804 : INFO : EPOCH 5 - PROGRESS: at 98.68% examples, 697666 words/s, in_qsize 5, out_qsize 0
# 2018-04-15 14:21:41,145 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-15 14:21:41,151 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-15 14:21:41,154 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-15 14:21:41,155 : INFO : EPOCH - 5 : training on 24392210 raw words (18498121 effective words) took 26.5s, 697840 effective words/s
# 2018-04-15 14:21:41,156 : INFO : training on a 121961050 raw words (92489316 effective words) took 134.3s, 688570 effective words/s

# %% [markdown]
# # Evaluation of word2vec model
# Google have released their testing set of about 20,000 syntactic and semantic test examples, following the “A is to B as C is to D” task: https://raw.githubusercontent.com/RaRe-Technologies/gensim/develop/gensim/test/test_data/questions-words.txt.

# %%
# %cd /Users/Allen/Documents/NLP/dataset
model.accuracy('questions-words.txt')
# Out:
# 2018-04-15 14:21:41,979 : INFO : precomputing L2-norms of word weight vectors
# /Users/Allen/Documents/NLP/dataset
# 2018-04-15 14:21:43,536 : INFO : capital-common-countries: 8.1% (22/272)
# 2018-04-15 14:21:44,738 : INFO : capital-world: 5.1% (15/293)
# 2018-04-15 14:21:44,931 : INFO : currency: 0.0% (0/40)
# 2018-04-15 14:21:49,123 : INFO : city-in-state: 2.2% (25/1121)
# 2018-04-15 14:21:50,430 : INFO : family: 58.2% (199/342)
# 2018-04-15 14:21:52,674 : INFO : gram1-adjective-to-adverb: 3.5% (21/600)
# 2018-04-15 14:21:53,294 : INFO : gram2-opposite: 9.6% (15/156)
# 2018-04-15 14:21:57,804 : INFO : gram3-comparative: 44.9% (534/1190)
# 2018-04-15 14:22:00,239 : INFO : gram4-superlative: 17.8% (116/650)
# 2018-04-15 14:22:02,878 : INFO : gram5-present-participle: 53.8% (378/702)
# 2018-04-15 14:22:05,134 : INFO : gram6-nationality-adjective: 4.1% (24/585)
# 2018-04-15 14:22:09,588 : INFO : gram7-past-tense: 42.7% (508/1190)
# 2018-04-15 14:22:14,290 : INFO : gram8-plural: 20.6% (259/1260)
# 2018-04-15 14:22:15,916 : INFO : gram9-plural-verbs: 38.1% (160/420)
# 2018-04-15 14:22:15,917 : INFO : total: 25.8% (2276/8821)
# [{'correct': [('ATHENS', 'GREECE', 'BANGKOK', 'THAILAND'),
#    ('ATHENS', 'GREECE', 'BERLIN', 'GERMANY'),
#    ('BEIJING', 'CHINA', 'TEHRAN', 'IRAN'),
#    ('BERLIN', 'GERMANY', 'HELSINKI', 'FINLAND'),
#    ('BERLIN', 'GERMANY', 'ROME', 'ITALY'),
#    ('CAIRO', 'EGYPT', 'ROME', 'ITALY'),
#    ('CAIRO', 'EGYPT', 'STOCKHOLM', 'SWEDEN'),
#    ('CANBERRA', 'AUSTRALIA', 'OTTAWA', 'CANADA'),
#    ('HELSINKI', 'FINLAND', 'TEHRAN', 'IRAN'),
#    ('HELSINKI', 'FINLAND', 'BERLIN', 'GERMANY'),
#    ('MOSCOW', 'RUSSIA', 'TEHRAN', 'IRAN'),
#    ('OSLO', 'NORWAY', 'CAIRO', 'EGYPT'),
#    ('OTTAWA', 'CANADA', 'ROME', 'ITALY'),
#    ('OTTAWA', 'CANADA', 'BERLIN', 'GERMANY'),
#    ('OTTAWA', 'CANADA', 'CANBERRA', 'AUSTRALIA'),
#    ('ROME', 'ITALY', 'STOCKHOLM', 'SWEDEN'),
#    ('ROME', 'ITALY', 'TEHRAN', 'IRAN'),
#    ('ROME', 'ITALY', 'BERLIN', 'GERMANY'),
#    ('STOCKHOLM', 'SWEDEN', 'CAIRO', 'EGYPT'),
#    ('STOCKHOLM', 'SWEDEN', 'ROME', 'ITALY'),
#    ('TOKYO', 'JAPAN', 'HELSINKI', 'FINLAND'),
#    ('TOKYO', 'JAPAN', 'MADRID', 'SPAIN')],
#   'incorrect': [('ATHENS', 'GREECE', 'BEIJING', 'CHINA'),
#    ('ATHENS', 'GREECE', 'CAIRO', 'EGYPT'),
#    ('ATHENS', 'GREECE', 'CANBERRA', 'AUSTRALIA'),
#    ('ATHENS', 'GREECE', 'HELSINKI', 'FINLAND'),
#    ('ATHENS', 'GREECE', 'LONDON', 'ENGLAND'),
#    ('ATHENS', 'GREECE', 'MADRID', 'SPAIN'),
#    ('ATHENS', 'GREECE', 'MOSCOW', 'RUSSIA'),
#    ('ATHENS', 'GREECE', 'OSLO', 'NORWAY'),
#    ('ATHENS', 'GREECE', 'OTTAWA', 'CANADA'),
#    ('ATHENS', 'GREECE', 'PARIS', 'FRANCE'),
#    ('ATHENS', 'GREECE', 'ROME', 'ITALY'),
#    ('ATHENS', 'GREECE', 'STOCKHOLM', 'SWEDEN'),
#    ('ATHENS', 'GREECE', 'TEHRAN', 'IRAN'),
#    ('ATHENS', 'GREECE', 'TOKYO', 'JAPAN'),
#    ('BANGKOK', 'THAILAND', 'BEIJING', 'CHINA'),
#    ('BANGKOK', 'THAILAND', 'BERLIN', 'GERMANY'),
#    ('BANGKOK', 'THAILAND', 'CAIRO', 'EGYPT'),
#    ('BANGKOK', 'THAILAND', 'CANBERRA', 'AUSTRALIA'),
#    ('BANGKOK', 'THAILAND', 'HELSINKI', 'FINLAND'),
#    ('BANGKOK', 'THAILAND', 'LONDON', 'ENGLAND'),
#    ('BANGKOK', 'THAILAND', 'MADRID', 'SPAIN'),
#    ('BANGKOK', 'THAILAND', 'MOSCOW', 'RUSSIA'),
#    ('BANGKOK', 'THAILAND', 'OSLO', 'NORWAY'),
#    ('BANGKOK', 'THAILAND', 'OTTAWA', 'CANADA'),
#    ('BANGKOK', 'THAILAND', 'PARIS', 'FRANCE'),
#    ('BANGKOK', 'THAILAND', 'ROME', 'ITALY'),
#    ('BANGKOK', 'THAILAND', 'STOCKHOLM', 'SWEDEN'),
#    ('BANGKOK', 'THAILAND', 'TEHRAN', 'IRAN'),
#    ('BANGKOK', 'THAILAND', 'TOKYO', 'JAPAN'),
#    ('BANGKOK', 'THAILAND', 'ATHENS', 'GREECE'),
#    ('BEIJING', 'CHINA', 'BERLIN', 'GERMANY'),
#    ('BEIJING', 'CHINA', 'CAIRO', 'EGYPT'),
#    ('BEIJING', 'CHINA', 'CANBERRA', 'AUSTRALIA'),
#    ('BEIJING', 'CHINA', 'HELSINKI', 'FINLAND'),
#    ('BEIJING', 'CHINA', 'LONDON', 'ENGLAND'),
#    ('BEIJING', 'CHINA', 'MADRID', 'SPAIN'),
#    ('BEIJING', 'CHINA', 'MOSCOW', 'RUSSIA'),
#    ('BEIJING', 'CHINA', 'OSLO', 'NORWAY'),
#    ('BEIJING', 'CHINA', 'OTTAWA', 'CANADA'),
#    ('BEIJING', 'CHINA', 'PARIS', 'FRANCE'),
#    ('BEIJING', 'CHINA', 'ROME', 'ITALY'),
#    ('BEIJING', 'CHINA', 'STOCKHOLM', 'SWEDEN'),
#    ('BEIJING', 'CHINA', 'TOKYO', 'JAPAN'),
#    ('BEIJING', 'CHINA', 'ATHENS', 'GREECE'),
#    ('BEIJING', 'CHINA', 'BANGKOK', 'THAILAND'),
#    ('BERLIN', 'GERMANY', 'CAIRO', 'EGYPT'),
#    ('BERLIN', 'GERMANY', 'CANBERRA', 'AUSTRALIA'),
#    ('BERLIN', 'GERMANY', 'LONDON', 'ENGLAND'),
#    ('BERLIN', 'GERMANY', 'MADRID', 'SPAIN'),
#    ('BERLIN', 'GERMANY', 'MOSCOW', 'RUSSIA'),
#    ('BERLIN', 'GERMANY', 'OSLO', 'NORWAY'),
#    ('BERLIN', 'GERMANY', 'OTTAWA', 'CANADA'),
#    ('BERLIN', 'GERMANY', 'PARIS', 'FRANCE'),
#    ('BERLIN', 'GERMANY', 'STOCKHOLM', 'SWEDEN'),
#    ('BERLIN', 'GERMANY', 'TEHRAN', 'IRAN'),
#    ('BERLIN', 'GERMANY', 'TOKYO', 'JAPAN'),
#    ('BERLIN', 'GERMANY', 'ATHENS', 'GREECE'),
#    ('BERLIN', 'GERMANY', 'BANGKOK', 'THAILAND'),
#    ('BERLIN', 'GERMANY', 'BEIJING', 'CHINA'),
#    ('CAIRO', 'EGYPT', 'CANBERRA', 'AUSTRALIA'),
#    ('CAIRO', 'EGYPT', 'HELSINKI', 'FINLAND'),
#    ('CAIRO', 'EGYPT', 'LONDON', 'ENGLAND'),
#    ('CAIRO', 'EGYPT', 'MADRID', 'SPAIN'),
#    ('CAIRO', 'EGYPT', 'MOSCOW', 'RUSSIA'),
#    ('CAIRO', 'EGYPT', 'OSLO', 'NORWAY'),
#    ('CAIRO', 'EGYPT', 'OTTAWA', 'CANADA'),
#    ('CAIRO', 'EGYPT', 'PARIS', 'FRANCE'),
#    ('CAIRO', 'EGYPT', 'TEHRAN', 'IRAN'),
#    ('CAIRO', 'EGYPT', 'TOKYO', 'JAPAN'),
#    ('CAIRO', 'EGYPT', 'ATHENS', 'GREECE'),
#    ('CAIRO', 'EGYPT', 'BANGKOK', 'THAILAND'),
#    ('CAIRO', 'EGYPT', 'BEIJING', 'CHINA'),
#    ('CAIRO', 'EGYPT', 'BERLIN', 'GERMANY'),
#    ('CANBERRA', 'AUSTRALIA', 'HELSINKI', 'FINLAND'),
#    ('CANBERRA', 'AUSTRALIA', 'LONDON', 'ENGLAND'),
#    ('CANBERRA', 'AUSTRALIA', 'MADRID', 'SPAIN'),
#    ('CANBERRA', 'AUSTRALIA', 'MOSCOW', 'RUSSIA'),
#    ('CANBERRA', 'AUSTRALIA', 'OSLO', 'NORWAY'),
#    ('CANBERRA', 'AUSTRALIA', 'PARIS', 'FRANCE'),
#    ('CANBERRA', 'AUSTRALIA', 'ROME', 'ITALY'),
#    ('CANBERRA', 'AUSTRALIA', 'STOCKHOLM', 'SWEDEN'),
#    ('CANBERRA', 'AUSTRALIA', 'TEHRAN', 'IRAN'),
#    ('CANBERRA', 'AUSTRALIA', 'TOKYO', 'JAPAN'),
#    ('CANBERRA', 'AUSTRALIA', 'ATHENS', 'GREECE'),
#    ('CANBERRA', 'AUSTRALIA', 'BANGKOK', 'THAILAND'),
#    ('CANBERRA', 'AUSTRALIA', 'BEIJING', 'CHINA'),
#    ('CANBERRA', 'AUSTRALIA', 'BERLIN', 'GERMANY'),
#    ('CANBERRA', 'AUSTRALIA', 'CAIRO', 'EGYPT'),
#    ('HELSINKI', 'FINLAND', 'LONDON', 'ENGLAND'),
#    ('HELSINKI', 'FINLAND', 'MADRID', 'SPAIN'),
#    ('HELSINKI', 'FINLAND', 'MOSCOW', 'RUSSIA'),
#    ('HELSINKI', 'FINLAND', 'OSLO', 'NORWAY'),
#    ('HELSINKI', 'FINLAND', 'OTTAWA', 'CANADA'),
#    ('HELSINKI', 'FINLAND', 'PARIS', 'FRANCE'),
#    ('HELSINKI', 'FINLAND', 'ROME', 'ITALY'),
#    ('HELSINKI', 'FINLAND', 'STOCKHOLM', 'SWEDEN'),
#    ('HELSINKI', 'FINLAND', 'TOKYO', 'JAPAN'),
#    ('HELSINKI', 'FINLAND', 'ATHENS', 'GREECE'),
#    ('HELSINKI', 'FINLAND', 'BANGKOK', 'THAILAND'),
#    ('HELSINKI', 'FINLAND', 'BEIJING', 'CHINA'),
#    ('HELSINKI', 'FINLAND', 'CAIRO', 'EGYPT'),
#    ('HELSINKI', 'FINLAND', 'CANBERRA', 'AUSTRALIA'),
#    ('LONDON', 'ENGLAND', 'MADRID', 'SPAIN'),
#    ('LONDON', 'ENGLAND', 'MOSCOW', 'RUSSIA'),
#    ('LONDON', 'ENGLAND', 'OSLO', 'NORWAY'),
#    ('LONDON', 'ENGLAND', 'OTTAWA', 'CANADA'),
#    ('LONDON', 'ENGLAND', 'PARIS', 'FRANCE'),
#    ('LONDON', 'ENGLAND', 'ROME', 'ITALY'),
#    ('LONDON', 'ENGLAND', 'STOCKHOLM', 'SWEDEN'),
#    ('LONDON', 'ENGLAND', 'TEHRAN', 'IRAN'),
#    ('LONDON', 'ENGLAND', 'TOKYO', 'JAPAN'),
#    ('LONDON', 'ENGLAND', 'ATHENS', 'GREECE'),
#    ('LONDON', 'ENGLAND', 'BANGKOK', 'THAILAND'),
#    ('LONDON', 'ENGLAND', 'BEIJING', 'CHINA'),
#    ('LONDON', 'ENGLAND', 'BERLIN', 'GERMANY'),
#    ('LONDON', 'ENGLAND', 'CAIRO', 'EGYPT'),
#    ('LONDON', 'ENGLAND', 'CANBERRA', 'AUSTRALIA'),
#    ('LONDON', 'ENGLAND', 'HELSINKI', 'FINLAND'),
#    ('MADRID', 'SPAIN', 'MOSCOW', 'RUSSIA'),
#    ('MADRID', 'SPAIN', 'OSLO', 'NORWAY'),
#    ('MADRID', 'SPAIN', 'OTTAWA', 'CANADA'),
#    ('MADRID', 'SPAIN', 'PARIS', 'FRANCE'),
#    ('MADRID', 'SPAIN', 'ROME', 'ITALY'),
#    ('MADRID', 'SPAIN', 'STOCKHOLM', 'SWEDEN'),
#    ('MADRID', 'SPAIN', 'TEHRAN', 'IRAN'),
#    ('MADRID', 'SPAIN', 'TOKYO', 'JAPAN'),
#    ('MADRID', 'SPAIN', 'ATHENS', 'GREECE'),
#    ('MADRID', 'SPAIN', 'BANGKOK', 'THAILAND'),
#    ('MADRID', 'SPAIN', 'BEIJING', 'CHINA'),
#    ('MADRID', 'SPAIN', 'BERLIN', 'GERMANY'),
#    ('MADRID', 'SPAIN', 'CAIRO', 'EGYPT'),
#    ('MADRID', 'SPAIN', 'CANBERRA', 'AUSTRALIA'),
#    ('MADRID', 'SPAIN', 'HELSINKI', 'FINLAND'),
#    ('MADRID', 'SPAIN', 'LONDON', 'ENGLAND'),
#    ('MOSCOW', 'RUSSIA', 'OSLO', 'NORWAY'),
#    ('MOSCOW', 'RUSSIA', 'OTTAWA', 'CANADA'),
#    ('MOSCOW', 'RUSSIA', 'PARIS', 'FRANCE'),
#    ('MOSCOW', 'RUSSIA', 'ROME', 'ITALY'),
#    ('MOSCOW', 'RUSSIA', 'STOCKHOLM', 'SWEDEN'),
#    ('MOSCOW', 'RUSSIA', 'TOKYO', 'JAPAN'),
#    ('MOSCOW', 'RUSSIA', 'ATHENS', 'GREECE'),
#    ('MOSCOW', 'RUSSIA', 'BANGKOK', 'THAILAND'),
#    ('MOSCOW', 'RUSSIA', 'BEIJING', 'CHINA'),
#    ('MOSCOW', 'RUSSIA', 'BERLIN', 'GERMANY'),
#    ('MOSCOW', 'RUSSIA', 'CAIRO', 'EGYPT'),
#    ('MOSCOW', 'RUSSIA', 'CANBERRA', 'AUSTRALIA'),
#    ('MOSCOW', 'RUSSIA', 'HELSINKI', 'FINLAND'),
#    ('MOSCOW', 'RUSSIA', 'LONDON', 'ENGLAND'),
#    ('MOSCOW', 'RUSSIA', 'MADRID', 'SPAIN'),
#    ('OSLO', 'NORWAY', 'OTTAWA', 'CANADA'),
#    ('OSLO', 'NORWAY', 'PARIS', 'FRANCE'),
#    ('OSLO', 'NORWAY', 'ROME', 'ITALY'),
#    ('OSLO', 'NORWAY', 'STOCKHOLM', 'SWEDEN'),
#    ('OSLO', 'NORWAY', 'TEHRAN', 'IRAN'),
#    ('OSLO', 'NORWAY', 'TOKYO', 'JAPAN'),
#    ('OSLO', 'NORWAY', 'ATHENS', 'GREECE'),
#    ('OSLO', 'NORWAY', 'BANGKOK', 'THAILAND'),
#    ('OSLO', 'NORWAY', 'BEIJING', 'CHINA'),
#    ('OSLO', 'NORWAY', 'BERLIN', 'GERMANY'),
#    ('OSLO', 'NORWAY', 'CANBERRA', 'AUSTRALIA'),
#    ('OSLO', 'NORWAY', 'HELSINKI', 'FINLAND'),
#    ('OSLO', 'NORWAY', 'LONDON', 'ENGLAND'),
#    ('OSLO', 'NORWAY', 'MADRID', 'SPAIN'),
#    ('OSLO', 'NORWAY', 'MOSCOW', 'RUSSIA'),
#    ('OTTAWA', 'CANADA', 'PARIS', 'FRANCE'),
#    ('OTTAWA', 'CANADA', 'STOCKHOLM', 'SWEDEN'),
#    ('OTTAWA', 'CANADA', 'TEHRAN', 'IRAN'),
#    ('OTTAWA', 'CANADA', 'TOKYO', 'JAPAN'),
#    ('OTTAWA', 'CANADA', 'ATHENS', 'GREECE'),
#    ('OTTAWA', 'CANADA', 'BANGKOK', 'THAILAND'),
#    ('OTTAWA', 'CANADA', 'BEIJING', 'CHINA'),
#    ('OTTAWA', 'CANADA', 'CAIRO', 'EGYPT'),
#    ('OTTAWA', 'CANADA', 'HELSINKI', 'FINLAND'),
#    ('OTTAWA', 'CANADA', 'LONDON', 'ENGLAND'),
#    ('OTTAWA', 'CANADA', 'MADRID', 'SPAIN'),
#    ('OTTAWA', 'CANADA', 'MOSCOW', 'RUSSIA'),
#    ('OTTAWA', 'CANADA', 'OSLO', 'NORWAY'),
#    ('PARIS', 'FRANCE', 'ROME', 'ITALY'),
#    ('PARIS', 'FRANCE', 'STOCKHOLM', 'SWEDEN'),
#    ('PARIS', 'FRANCE', 'TEHRAN', 'IRAN'),
#    ('PARIS', 'FRANCE', 'TOKYO', 'JAPAN'),
#    ('PARIS', 'FRANCE', 'ATHENS', 'GREECE'),
#    ('PARIS', 'FRANCE', 'BANGKOK', 'THAILAND'),
#    ('PARIS', 'FRANCE', 'BEIJING', 'CHINA'),
#    ('PARIS', 'FRANCE', 'BERLIN', 'GERMANY'),
#    ('PARIS', 'FRANCE', 'CAIRO', 'EGYPT'),
#    ('PARIS', 'FRANCE', 'CANBERRA', 'AUSTRALIA'),
#    ('PARIS', 'FRANCE', 'HELSINKI', 'FINLAND'),
#    ('PARIS', 'FRANCE', 'LONDON', 'ENGLAND'),
#    ('PARIS', 'FRANCE', 'MADRID', 'SPAIN'),
#    ('PARIS', 'FRANCE', 'MOSCOW', 'RUSSIA'),
#    ('PARIS', 'FRANCE', 'OSLO', 'NORWAY'),
#    ('PARIS', 'FRANCE', 'OTTAWA', 'CANADA'),
#    ('ROME', 'ITALY', 'TOKYO', 'JAPAN'),
#    ('ROME', 'ITALY', 'ATHENS', 'GREECE'),
#    ('ROME', 'ITALY', 'BANGKOK', 'THAILAND'),
#    ('ROME', 'ITALY', 'BEIJING', 'CHINA'),
#    ('ROME', 'ITALY', 'CAIRO', 'EGYPT'),
#    ('ROME', 'ITALY', 'CANBERRA', 'AUSTRALIA'),
#    ('ROME', 'ITALY', 'HELSINKI', 'FINLAND'),
#    ('ROME', 'ITALY', 'LONDON', 'ENGLAND'),
#    ('ROME', 'ITALY', 'MADRID', 'SPAIN'),
#    ('ROME', 'ITALY', 'MOSCOW', 'RUSSIA'),
#    ('ROME', 'ITALY', 'OSLO', 'NORWAY'),
#    ('ROME', 'ITALY', 'OTTAWA', 'CANADA'),
#    ('ROME', 'ITALY', 'PARIS', 'FRANCE'),
#    ('STOCKHOLM', 'SWEDEN', 'TEHRAN', 'IRAN'),
#    ('STOCKHOLM', 'SWEDEN', 'TOKYO', 'JAPAN'),
#    ('STOCKHOLM', 'SWEDEN', 'ATHENS', 'GREECE'),
#    ('STOCKHOLM', 'SWEDEN', 'BANGKOK', 'THAILAND'),
#    ('STOCKHOLM', 'SWEDEN', 'BEIJING', 'CHINA'),
#    ('STOCKHOLM', 'SWEDEN', 'BERLIN', 'GERMANY'),
#    ('STOCKHOLM', 'SWEDEN', 'CANBERRA', 'AUSTRALIA'),
#    ('STOCKHOLM', 'SWEDEN', 'HELSINKI', 'FINLAND'),
#    ('STOCKHOLM', 'SWEDEN', 'LONDON', 'ENGLAND'),
#    ('STOCKHOLM', 'SWEDEN', 'MADRID', 'SPAIN'),
#    ('STOCKHOLM', 'SWEDEN', 'MOSCOW', 'RUSSIA'),
#    ('STOCKHOLM', 'SWEDEN', 'OSLO', 'NORWAY'),
#    ('STOCKHOLM', 'SWEDEN', 'OTTAWA', 'CANADA'),
#    ('STOCKHOLM', 'SWEDEN', 'PARIS', 'FRANCE'),
#    ('TEHRAN', 'IRAN', 'TOKYO', 'JAPAN'),
#    ('TEHRAN', 'IRAN', 'ATHENS', 'GREECE'),
#    ('TEHRAN', 'IRAN', 'BANGKOK', 'THAILAND'),
#    ('TEHRAN', 'IRAN', 'BEIJING', 'CHINA'),
#    ('TEHRAN', 'IRAN', 'BERLIN', 'GERMANY'),
#    ('TEHRAN', 'IRAN', 'CAIRO', 'EGYPT'),
#    ('TEHRAN', 'IRAN', 'CANBERRA', 'AUSTRALIA'),
#    ('TEHRAN', 'IRAN', 'HELSINKI', 'FINLAND'),
#    ('TEHRAN', 'IRAN', 'LONDON', 'ENGLAND'),
#    ('TEHRAN', 'IRAN', 'MADRID', 'SPAIN'),
#    ('TEHRAN', 'IRAN', 'MOSCOW', 'RUSSIA'),
#    ('TEHRAN', 'IRAN', 'OSLO', 'NORWAY'),
#    ('TEHRAN', 'IRAN', 'OTTAWA', 'CANADA'),
#    ('TEHRAN', 'IRAN', 'PARIS', 'FRANCE'),
#    ('TEHRAN', 'IRAN', 'ROME', 'ITALY'),
#    ('TEHRAN', 'IRAN', 'STOCKHOLM', 'SWEDEN'),
#    ('TOKYO', 'JAPAN', 'ATHENS', 'GREECE'),
#    ('TOKYO', 'JAPAN', 'BANGKOK', 'THAILAND'),
#    ('TOKYO', 'JAPAN', 'BEIJING', 'CHINA'),
#    ('TOKYO', 'JAPAN', 'BERLIN', 'GERMANY'),
#    ('TOKYO', 'JAPAN', 'CAIRO', 'EGYPT'),
#    ('TOKYO', 'JAPAN', 'CANBERRA', 'AUSTRALIA'),
#    ('TOKYO', 'JAPAN', 'LONDON', 'ENGLAND'),
#    ('TOKYO', 'JAPAN', 'MOSCOW', 'RUSSIA'),
#    ('TOKYO', 'JAPAN', 'OSLO', 'NORWAY'),
#    ('TOKYO', 'JAPAN', 'OTTAWA', 'CANADA'),
#    ('TOKYO', 'JAPAN', 'PARIS', 'FRANCE'),
#    ('TOKYO', 'JAPAN', 'ROME', 'ITALY'),
#    ('TOKYO', 'JAPAN', 'STOCKHOLM', 'SWEDEN'),
#    ('TOKYO', 'JAPAN', 'TEHRAN', 'IRAN')],
#   'section': 'capital-common-countries'},
#  {'correct': [('ATHENS', 'GREECE', 'BANGKOK', 'THAILAND'),
#    ('ATHENS', 'GREECE', 'BERLIN', 'GERMANY'),
#    ('BERLIN', 'GERMANY', 'DUBLIN', 'IRELAND'),
#    ('BERLIN', 'GERMANY', 'HELSINKI', 'FINLAND'),
#    ('BRUSSELS', 'BELGIUM', 'DUBLIN', 'IRELAND'),
#    ('CAIRO', 'EGYPT', 'DUBLIN', 'IRELAND'),
#    ('HELSINKI', 'FINLAND', 'LISBON', 'PORTUGAL'),
#    ('LISBON', 'PORTUGAL', 'MADRID', 'SPAIN'),
#    ('MANILA', 'PHILIPPINES', 'TEHRAN', 'IRAN'),
#    ('MOSCOW', 'RUSSIA', 'TEHRAN', 'IRAN'),
#    ('OTTAWA', 'CANADA', 'ROME', 'ITALY'),
#    ('ROME', 'ITALY', 'STOCKHOLM', 'SWEDEN'),
#    ('ROME', 'ITALY', 'TEHRAN', 'IRAN'),
#    ('SOFIA', 'BULGARIA', 'TEHRAN', 'IRAN'),
#    ('WARSAW', 'POLAND', 'BERLIN', 'GERMANY')],
#   'incorrect': [('ATHENS', 'GREECE', 'BEIJING', 'CHINA'),
#    ('ATHENS', 'GREECE', 'BRUSSELS', 'BELGIUM'),
#    ('ATHENS', 'GREECE', 'BUDAPEST', 'HUNGARY'),
#    ('ATHENS', 'GREECE', 'CAIRO', 'EGYPT'),
#    ('ATHENS', 'GREECE', 'CANBERRA', 'AUSTRALIA'),
#    ('ATHENS', 'GREECE', 'COPENHAGEN', 'DENMARK'),
#    ('ATHENS', 'GREECE', 'DUBLIN', 'IRELAND'),
#    ('ATHENS', 'GREECE', 'HELSINKI', 'FINLAND'),
#    ('ATHENS', 'GREECE', 'JAKARTA', 'INDONESIA'),
#    ('BANGKOK', 'THAILAND', 'BEIJING', 'CHINA'),
#    ('BANGKOK', 'THAILAND', 'BERLIN', 'GERMANY'),
#    ('BANGKOK', 'THAILAND', 'BRUSSELS', 'BELGIUM'),
#    ('BANGKOK', 'THAILAND', 'BUDAPEST', 'HUNGARY'),
#    ('BANGKOK', 'THAILAND', 'CAIRO', 'EGYPT'),
#    ('BANGKOK', 'THAILAND', 'CANBERRA', 'AUSTRALIA'),
#    ('BANGKOK', 'THAILAND', 'COPENHAGEN', 'DENMARK'),
#    ('BANGKOK', 'THAILAND', 'DUBLIN', 'IRELAND'),
#    ('BANGKOK', 'THAILAND', 'HELSINKI', 'FINLAND'),
#    ('BANGKOK', 'THAILAND', 'JAKARTA', 'INDONESIA'),
#    ('BEIJING', 'CHINA', 'BERLIN', 'GERMANY'),
#    ('BEIJING', 'CHINA', 'BRUSSELS', 'BELGIUM'),
#    ('BEIJING', 'CHINA', 'BUDAPEST', 'HUNGARY'),
#    ('BEIJING', 'CHINA', 'CAIRO', 'EGYPT'),
#    ('BEIJING', 'CHINA', 'CANBERRA', 'AUSTRALIA'),
#    ('BEIJING', 'CHINA', 'COPENHAGEN', 'DENMARK'),
#    ('BEIJING', 'CHINA', 'DUBLIN', 'IRELAND'),
#    ('BEIJING', 'CHINA', 'HELSINKI', 'FINLAND'),
#    ('BEIJING', 'CHINA', 'JAKARTA', 'INDONESIA'),
#    ('BEIJING', 'CHINA', 'KINGSTON', 'JAMAICA'),
#    ('BERLIN', 'GERMANY', 'BRUSSELS', 'BELGIUM'),
#    ('BERLIN', 'GERMANY', 'BUDAPEST', 'HUNGARY'),
#    ('BERLIN', 'GERMANY', 'CAIRO', 'EGYPT'),
#    ('BERLIN', 'GERMANY', 'CANBERRA', 'AUSTRALIA'),
#    ('BERLIN', 'GERMANY', 'COPENHAGEN', 'DENMARK'),
#    ('BERLIN', 'GERMANY', 'JAKARTA', 'INDONESIA'),
#    ('BERLIN', 'GERMANY', 'KINGSTON', 'JAMAICA'),
#    ('BERLIN', 'GERMANY', 'LIMA', 'PERU'),
#    ('BERLIN', 'GERMANY', 'LISBON', 'PORTUGAL'),
#    ('BRUSSELS', 'BELGIUM', 'BUDAPEST', 'HUNGARY'),
#    ('BRUSSELS', 'BELGIUM', 'CAIRO', 'EGYPT'),
#    ('BRUSSELS', 'BELGIUM', 'CANBERRA', 'AUSTRALIA'),
#    ('BRUSSELS', 'BELGIUM', 'COPENHAGEN', 'DENMARK'),
#    ('BRUSSELS', 'BELGIUM', 'HELSINKI', 'FINLAND'),
#    ('BRUSSELS', 'BELGIUM', 'JAKARTA', 'INDONESIA'),
#    ('BRUSSELS', 'BELGIUM', 'KINGSTON', 'JAMAICA'),
#    ('BRUSSELS', 'BELGIUM', 'LIMA', 'PERU'),
#    ('BRUSSELS', 'BELGIUM', 'LISBON', 'PORTUGAL'),
#    ('BRUSSELS', 'BELGIUM', 'LONDON', 'ENGLAND'),
#    ('BUDAPEST', 'HUNGARY', 'CAIRO', 'EGYPT'),
#    ('BUDAPEST', 'HUNGARY', 'CANBERRA', 'AUSTRALIA'),
#    ('BUDAPEST', 'HUNGARY', 'COPENHAGEN', 'DENMARK'),
#    ('BUDAPEST', 'HUNGARY', 'DUBLIN', 'IRELAND'),
#    ('BUDAPEST', 'HUNGARY', 'HELSINKI', 'FINLAND'),
#    ('BUDAPEST', 'HUNGARY', 'JAKARTA', 'INDONESIA'),
#    ('BUDAPEST', 'HUNGARY', 'KINGSTON', 'JAMAICA'),
#    ('BUDAPEST', 'HUNGARY', 'LIMA', 'PERU'),
#    ('BUDAPEST', 'HUNGARY', 'LISBON', 'PORTUGAL'),
#    ('BUDAPEST', 'HUNGARY', 'LONDON', 'ENGLAND'),
#    ('BUDAPEST', 'HUNGARY', 'MADRID', 'SPAIN'),
#    ('CAIRO', 'EGYPT', 'CANBERRA', 'AUSTRALIA'),
#    ('CAIRO', 'EGYPT', 'COPENHAGEN', 'DENMARK'),
#    ('CAIRO', 'EGYPT', 'HELSINKI', 'FINLAND'),
#    ('CAIRO', 'EGYPT', 'JAKARTA', 'INDONESIA'),
#    ('CAIRO', 'EGYPT', 'KINGSTON', 'JAMAICA'),
#    ('CAIRO', 'EGYPT', 'LIMA', 'PERU'),
#    ('CAIRO', 'EGYPT', 'LISBON', 'PORTUGAL'),
#    ('CAIRO', 'EGYPT', 'LONDON', 'ENGLAND'),
#    ('CAIRO', 'EGYPT', 'MADRID', 'SPAIN'),
#    ('CAIRO', 'EGYPT', 'MANILA', 'PHILIPPINES'),
#    ('CANBERRA', 'AUSTRALIA', 'COPENHAGEN', 'DENMARK'),
#    ('CANBERRA', 'AUSTRALIA', 'DUBLIN', 'IRELAND'),
#    ('CANBERRA', 'AUSTRALIA', 'HELSINKI', 'FINLAND'),
#    ('CANBERRA', 'AUSTRALIA', 'JAKARTA', 'INDONESIA'),
#    ('CANBERRA', 'AUSTRALIA', 'KINGSTON', 'JAMAICA'),
#    ('CANBERRA', 'AUSTRALIA', 'LIMA', 'PERU'),
#    ('CANBERRA', 'AUSTRALIA', 'LISBON', 'PORTUGAL'),
#    ('CANBERRA', 'AUSTRALIA', 'LONDON', 'ENGLAND'),
#    ('CANBERRA', 'AUSTRALIA', 'MADRID', 'SPAIN'),
#    ('CANBERRA', 'AUSTRALIA', 'MANILA', 'PHILIPPINES'),
#    ('COPENHAGEN', 'DENMARK', 'DUBLIN', 'IRELAND'),
#    ('COPENHAGEN', 'DENMARK', 'HELSINKI', 'FINLAND'),
#    ('COPENHAGEN', 'DENMARK', 'JAKARTA', 'INDONESIA'),
#    ('COPENHAGEN', 'DENMARK', 'KINGSTON', 'JAMAICA'),
#    ('COPENHAGEN', 'DENMARK', 'LIMA', 'PERU'),
#    ('COPENHAGEN', 'DENMARK', 'LISBON', 'PORTUGAL'),
#    ('COPENHAGEN', 'DENMARK', 'LONDON', 'ENGLAND'),
#    ('COPENHAGEN', 'DENMARK', 'MADRID', 'SPAIN'),
#    ('COPENHAGEN', 'DENMARK', 'MANILA', 'PHILIPPINES'),
#    ('DUBLIN', 'IRELAND', 'HELSINKI', 'FINLAND'),
#    ('DUBLIN', 'IRELAND', 'JAKARTA', 'INDONESIA'),
#    ('DUBLIN', 'IRELAND', 'KINGSTON', 'JAMAICA'),
#    ('DUBLIN', 'IRELAND', 'LIMA', 'PERU'),
#    ('DUBLIN', 'IRELAND', 'LISBON', 'PORTUGAL'),
#    ('DUBLIN', 'IRELAND', 'LONDON', 'ENGLAND'),
#    ('DUBLIN', 'IRELAND', 'MADRID', 'SPAIN'),
#    ('DUBLIN', 'IRELAND', 'MANILA', 'PHILIPPINES'),
#    ('DUBLIN', 'IRELAND', 'MOSCOW', 'RUSSIA'),
#    ('HELSINKI', 'FINLAND', 'JAKARTA', 'INDONESIA'),
#    ('HELSINKI', 'FINLAND', 'KINGSTON', 'JAMAICA'),
#    ('HELSINKI', 'FINLAND', 'LIMA', 'PERU'),
#    ('HELSINKI', 'FINLAND', 'LONDON', 'ENGLAND'),
#    ('HELSINKI', 'FINLAND', 'MADRID', 'SPAIN'),
#    ('HELSINKI', 'FINLAND', 'MANILA', 'PHILIPPINES'),
#    ('HELSINKI', 'FINLAND', 'MOSCOW', 'RUSSIA'),
#    ('HELSINKI', 'FINLAND', 'OSLO', 'NORWAY'),
#    ('HELSINKI', 'FINLAND', 'OTTAWA', 'CANADA'),
#    ('HELSINKI', 'FINLAND', 'PARIS', 'FRANCE'),
#    ('JAKARTA', 'INDONESIA', 'KINGSTON', 'JAMAICA'),
#    ('JAKARTA', 'INDONESIA', 'LIMA', 'PERU'),
#    ('JAKARTA', 'INDONESIA', 'LISBON', 'PORTUGAL'),
#    ('JAKARTA', 'INDONESIA', 'LONDON', 'ENGLAND'),
#    ('JAKARTA', 'INDONESIA', 'MADRID', 'SPAIN'),
#    ('JAKARTA', 'INDONESIA', 'MANILA', 'PHILIPPINES'),
#    ('JAKARTA', 'INDONESIA', 'MOSCOW', 'RUSSIA'),
#    ('JAKARTA', 'INDONESIA', 'OSLO', 'NORWAY'),
#    ('JAKARTA', 'INDONESIA', 'OTTAWA', 'CANADA'),
#    ('JAKARTA', 'INDONESIA', 'PARIS', 'FRANCE'),
#    ('KINGSTON', 'JAMAICA', 'LIMA', 'PERU'),
#    ('KINGSTON', 'JAMAICA', 'LISBON', 'PORTUGAL'),
#    ('KINGSTON', 'JAMAICA', 'LONDON', 'ENGLAND'),
#    ('KINGSTON', 'JAMAICA', 'MADRID', 'SPAIN'),
#    ('KINGSTON', 'JAMAICA', 'MANILA', 'PHILIPPINES'),
#    ('KINGSTON', 'JAMAICA', 'MOSCOW', 'RUSSIA'),
#    ('KINGSTON', 'JAMAICA', 'OSLO', 'NORWAY'),
#    ('KINGSTON', 'JAMAICA', 'OTTAWA', 'CANADA'),
#    ('KINGSTON', 'JAMAICA', 'PARIS', 'FRANCE'),
#    ('KINGSTON', 'JAMAICA', 'ROME', 'ITALY'),
#    ('KINGSTON', 'JAMAICA', 'SOFIA', 'BULGARIA'),
#    ('KINGSTON', 'JAMAICA', 'STOCKHOLM', 'SWEDEN'),
#    ('LIMA', 'PERU', 'LISBON', 'PORTUGAL'),
#    ('LIMA', 'PERU', 'LONDON', 'ENGLAND'),
#    ('LIMA', 'PERU', 'MADRID', 'SPAIN'),
#    ('LIMA', 'PERU', 'MANILA', 'PHILIPPINES'),
#    ('LIMA', 'PERU', 'MOSCOW', 'RUSSIA'),
#    ('LIMA', 'PERU', 'OSLO', 'NORWAY'),
#    ('LIMA', 'PERU', 'OTTAWA', 'CANADA'),
#    ('LIMA', 'PERU', 'PARIS', 'FRANCE'),
#    ('LIMA', 'PERU', 'ROME', 'ITALY'),
#    ('LIMA', 'PERU', 'SOFIA', 'BULGARIA'),
#    ('LIMA', 'PERU', 'STOCKHOLM', 'SWEDEN'),
#    ('LIMA', 'PERU', 'TAIPEI', 'TAIWAN'),
#    ('LISBON', 'PORTUGAL', 'LONDON', 'ENGLAND'),
#    ('LISBON', 'PORTUGAL', 'MANILA', 'PHILIPPINES'),
#    ('LISBON', 'PORTUGAL', 'MOSCOW', 'RUSSIA'),
#    ('LISBON', 'PORTUGAL', 'OSLO', 'NORWAY'),
#    ('LISBON', 'PORTUGAL', 'OTTAWA', 'CANADA'),
#    ('LISBON', 'PORTUGAL', 'PARIS', 'FRANCE'),
#    ('LISBON', 'PORTUGAL', 'ROME', 'ITALY'),
#    ('LISBON', 'PORTUGAL', 'SOFIA', 'BULGARIA'),
#    ('LISBON', 'PORTUGAL', 'STOCKHOLM', 'SWEDEN'),
#    ('LISBON', 'PORTUGAL', 'TAIPEI', 'TAIWAN'),
#    ('LONDON', 'ENGLAND', 'MADRID', 'SPAIN'),
#    ('LONDON', 'ENGLAND', 'MANILA', 'PHILIPPINES'),
#    ('LONDON', 'ENGLAND', 'MOSCOW', 'RUSSIA'),
#    ('LONDON', 'ENGLAND', 'OSLO', 'NORWAY'),
#    ('LONDON', 'ENGLAND', 'OTTAWA', 'CANADA'),
#    ('LONDON', 'ENGLAND', 'PARIS', 'FRANCE'),
#    ('LONDON', 'ENGLAND', 'ROME', 'ITALY'),
#    ('LONDON', 'ENGLAND', 'SOFIA', 'BULGARIA'),
#    ('LONDON', 'ENGLAND', 'STOCKHOLM', 'SWEDEN'),
#    ('LONDON', 'ENGLAND', 'TAIPEI', 'TAIWAN'),
#    ('MADRID', 'SPAIN', 'MANILA', 'PHILIPPINES'),
#    ('MADRID', 'SPAIN', 'MOSCOW', 'RUSSIA'),
#    ('MADRID', 'SPAIN', 'OSLO', 'NORWAY'),
#    ('MADRID', 'SPAIN', 'OTTAWA', 'CANADA'),
#    ('MADRID', 'SPAIN', 'PARIS', 'FRANCE'),
#    ('MADRID', 'SPAIN', 'ROME', 'ITALY'),
#    ('MADRID', 'SPAIN', 'SOFIA', 'BULGARIA'),
#    ('MADRID', 'SPAIN', 'STOCKHOLM', 'SWEDEN'),
#    ('MADRID', 'SPAIN', 'TAIPEI', 'TAIWAN'),
#    ('MADRID', 'SPAIN', 'TEHRAN', 'IRAN'),
#    ('MANILA', 'PHILIPPINES', 'MOSCOW', 'RUSSIA'),
#    ('MANILA', 'PHILIPPINES', 'OSLO', 'NORWAY'),
#    ('MANILA', 'PHILIPPINES', 'OTTAWA', 'CANADA'),
#    ('MANILA', 'PHILIPPINES', 'PARIS', 'FRANCE'),
#    ('MANILA', 'PHILIPPINES', 'ROME', 'ITALY'),
#    ('MANILA', 'PHILIPPINES', 'SOFIA', 'BULGARIA'),
#    ('MANILA', 'PHILIPPINES', 'STOCKHOLM', 'SWEDEN'),
#    ('MANILA', 'PHILIPPINES', 'TAIPEI', 'TAIWAN'),
#    ('MANILA', 'PHILIPPINES', 'TOKYO', 'JAPAN'),
#    ('MOSCOW', 'RUSSIA', 'OSLO', 'NORWAY'),
#    ('MOSCOW', 'RUSSIA', 'OTTAWA', 'CANADA'),
#    ('MOSCOW', 'RUSSIA', 'PARIS', 'FRANCE'),
#    ('MOSCOW', 'RUSSIA', 'ROME', 'ITALY'),
#    ('MOSCOW', 'RUSSIA', 'SOFIA', 'BULGARIA'),
#    ('MOSCOW', 'RUSSIA', 'STOCKHOLM', 'SWEDEN'),
#    ('MOSCOW', 'RUSSIA', 'TAIPEI', 'TAIWAN'),
#    ('MOSCOW', 'RUSSIA', 'TOKYO', 'JAPAN'),
#    ('MOSCOW', 'RUSSIA', 'VIENNA', 'AUSTRIA'),
#    ('MOSCOW', 'RUSSIA', 'WARSAW', 'POLAND'),
#    ('OSLO', 'NORWAY', 'OTTAWA', 'CANADA'),
#    ('OSLO', 'NORWAY', 'PARIS', 'FRANCE'),
#    ('OSLO', 'NORWAY', 'ROME', 'ITALY'),
#    ('OSLO', 'NORWAY', 'SOFIA', 'BULGARIA'),
#    ('OSLO', 'NORWAY', 'STOCKHOLM', 'SWEDEN'),
#    ('OSLO', 'NORWAY', 'TAIPEI', 'TAIWAN'),
#    ('OSLO', 'NORWAY', 'TEHRAN', 'IRAN'),
#    ('OSLO', 'NORWAY', 'TOKYO', 'JAPAN'),
#    ('OSLO', 'NORWAY', 'VIENNA', 'AUSTRIA'),
#    ('OSLO', 'NORWAY', 'WARSAW', 'POLAND'),
#    ('OTTAWA', 'CANADA', 'PARIS', 'FRANCE'),
#    ('OTTAWA', 'CANADA', 'SOFIA', 'BULGARIA'),
#    ('OTTAWA', 'CANADA', 'STOCKHOLM', 'SWEDEN'),
#    ('OTTAWA', 'CANADA', 'TAIPEI', 'TAIWAN'),
#    ('OTTAWA', 'CANADA', 'TEHRAN', 'IRAN'),
#    ('OTTAWA', 'CANADA', 'TOKYO', 'JAPAN'),
#    ('OTTAWA', 'CANADA', 'VIENNA', 'AUSTRIA'),
#    ('OTTAWA', 'CANADA', 'WARSAW', 'POLAND'),
#    ('PARIS', 'FRANCE', 'ROME', 'ITALY'),
#    ('PARIS', 'FRANCE', 'SOFIA', 'BULGARIA'),
#    ('PARIS', 'FRANCE', 'STOCKHOLM', 'SWEDEN'),
#    ('PARIS', 'FRANCE', 'TAIPEI', 'TAIWAN'),
#    ('PARIS', 'FRANCE', 'TEHRAN', 'IRAN'),
#    ('PARIS', 'FRANCE', 'TOKYO', 'JAPAN'),
#    ('PARIS', 'FRANCE', 'VIENNA', 'AUSTRIA'),
#    ('PARIS', 'FRANCE', 'WARSAW', 'POLAND'),
#    ('ROME', 'ITALY', 'SOFIA', 'BULGARIA'),
#    ('ROME', 'ITALY', 'TAIPEI', 'TAIWAN'),
#    ('ROME', 'ITALY', 'TOKYO', 'JAPAN'),
#    ('ROME', 'ITALY', 'VIENNA', 'AUSTRIA'),
#    ('ROME', 'ITALY', 'WARSAW', 'POLAND'),
#    ('ROME', 'ITALY', 'ATHENS', 'GREECE'),
#    ('SOFIA', 'BULGARIA', 'STOCKHOLM', 'SWEDEN'),
#    ('SOFIA', 'BULGARIA', 'TAIPEI', 'TAIWAN'),
#    ('SOFIA', 'BULGARIA', 'TOKYO', 'JAPAN'),
#    ('SOFIA', 'BULGARIA', 'VIENNA', 'AUSTRIA'),
#    ('SOFIA', 'BULGARIA', 'WARSAW', 'POLAND'),
#    ('SOFIA', 'BULGARIA', 'ATHENS', 'GREECE'),
#    ('SOFIA', 'BULGARIA', 'BANGKOK', 'THAILAND'),
#    ('SOFIA', 'BULGARIA', 'BEIJING', 'CHINA'),
#    ('STOCKHOLM', 'SWEDEN', 'TAIPEI', 'TAIWAN'),
#    ('STOCKHOLM', 'SWEDEN', 'TEHRAN', 'IRAN'),
#    ('STOCKHOLM', 'SWEDEN', 'TOKYO', 'JAPAN'),
#    ('STOCKHOLM', 'SWEDEN', 'VIENNA', 'AUSTRIA'),
#    ('STOCKHOLM', 'SWEDEN', 'WARSAW', 'POLAND'),
#    ('STOCKHOLM', 'SWEDEN', 'ATHENS', 'GREECE'),
#    ('STOCKHOLM', 'SWEDEN', 'BANGKOK', 'THAILAND'),
#    ('STOCKHOLM', 'SWEDEN', 'BEIJING', 'CHINA'),
#    ('TAIPEI', 'TAIWAN', 'TEHRAN', 'IRAN'),
#    ('TAIPEI', 'TAIWAN', 'TOKYO', 'JAPAN'),
#    ('TAIPEI', 'TAIWAN', 'VIENNA', 'AUSTRIA'),
#    ('TAIPEI', 'TAIWAN', 'WARSAW', 'POLAND'),
#    ('TAIPEI', 'TAIWAN', 'ATHENS', 'GREECE'),
#    ('TAIPEI', 'TAIWAN', 'BANGKOK', 'THAILAND'),
#    ('TAIPEI', 'TAIWAN', 'BEIJING', 'CHINA'),
#    ('TEHRAN', 'IRAN', 'TOKYO', 'JAPAN'),
#    ('TEHRAN', 'IRAN', 'VIENNA', 'AUSTRIA'),
#    ('TEHRAN', 'IRAN', 'WARSAW', 'POLAND'),
#    ('TEHRAN', 'IRAN', 'ATHENS', 'GREECE'),
#    ('TEHRAN', 'IRAN', 'BANGKOK', 'THAILAND'),
#    ('TEHRAN', 'IRAN', 'BEIJING', 'CHINA'),
#    ('TEHRAN', 'IRAN', 'BERLIN', 'GERMANY'),
#    ('TEHRAN', 'IRAN', 'BRUSSELS', 'BELGIUM'),
#    ('TOKYO', 'JAPAN', 'VIENNA', 'AUSTRIA'),
#    ('TOKYO', 'JAPAN', 'WARSAW', 'POLAND'),
#    ('TOKYO', 'JAPAN', 'ATHENS', 'GREECE'),
#    ('TOKYO', 'JAPAN', 'BANGKOK', 'THAILAND'),
#    ('TOKYO', 'JAPAN', 'BEIJING', 'CHINA'),
#    ('TOKYO', 'JAPAN', 'BERLIN', 'GERMANY'),
#    ('TOKYO', 'JAPAN', 'BRUSSELS', 'BELGIUM'),
#    ('TOKYO', 'JAPAN', 'BUDAPEST', 'HUNGARY'),
#    ('VIENNA', 'AUSTRIA', 'WARSAW', 'POLAND'),
#    ('VIENNA', 'AUSTRIA', 'ATHENS', 'GREECE'),
#    ('VIENNA', 'AUSTRIA', 'BANGKOK', 'THAILAND'),
#    ('VIENNA', 'AUSTRIA', 'BEIJING', 'CHINA'),
#    ('VIENNA', 'AUSTRIA', 'BERLIN', 'GERMANY'),
#    ('VIENNA', 'AUSTRIA', 'BRUSSELS', 'BELGIUM'),
#    ('VIENNA', 'AUSTRIA', 'BUDAPEST', 'HUNGARY'),
#    ('VIENNA', 'AUSTRIA', 'CAIRO', 'EGYPT'),
#    ('VIENNA', 'AUSTRIA', 'CANBERRA', 'AUSTRALIA'),
#    ('WARSAW', 'POLAND', 'ATHENS', 'GREECE'),
#    ('WARSAW', 'POLAND', 'BANGKOK', 'THAILAND'),
#    ('WARSAW', 'POLAND', 'BEIJING', 'CHINA'),
#    ('WARSAW', 'POLAND', 'BRUSSELS', 'BELGIUM'),
#    ('WARSAW', 'POLAND', 'BUDAPEST', 'HUNGARY'),
#    ('WARSAW', 'POLAND', 'CAIRO', 'EGYPT'),
#    ('WARSAW', 'POLAND', 'CANBERRA', 'AUSTRALIA'),
#    ('WARSAW', 'POLAND', 'COPENHAGEN', 'DENMARK')],
#   'section': 'capital-world'},
#  {'correct': [],
#   'incorrect': [('BRAZIL', 'REAL', 'CANADA', 'DOLLAR'),
#    ('BRAZIL', 'REAL', 'EUROPE', 'EURO'),
#    ('BRAZIL', 'REAL', 'JAPAN', 'YEN'),
#    ('BRAZIL', 'REAL', 'KOREA', 'WON'),
#    ('BRAZIL', 'REAL', 'USA', 'DOLLAR'),
#    ('BRAZIL', 'REAL', 'VIETNAM', 'DONG'),
#    ('CANADA', 'DOLLAR', 'EUROPE', 'EURO'),
#    ('CANADA', 'DOLLAR', 'JAPAN', 'YEN'),
#    ('CANADA', 'DOLLAR', 'KOREA', 'WON'),
#    ('CANADA', 'DOLLAR', 'VIETNAM', 'DONG'),
#    ('CANADA', 'DOLLAR', 'BRAZIL', 'REAL'),
#    ('EUROPE', 'EURO', 'JAPAN', 'YEN'),
#    ('EUROPE', 'EURO', 'KOREA', 'WON'),
#    ('EUROPE', 'EURO', 'USA', 'DOLLAR'),
#    ('EUROPE', 'EURO', 'VIETNAM', 'DONG'),
#    ('EUROPE', 'EURO', 'BRAZIL', 'REAL'),
#    ('EUROPE', 'EURO', 'CANADA', 'DOLLAR'),
#    ('JAPAN', 'YEN', 'KOREA', 'WON'),
#    ('JAPAN', 'YEN', 'USA', 'DOLLAR'),
#    ('JAPAN', 'YEN', 'VIETNAM', 'DONG'),
#    ('JAPAN', 'YEN', 'BRAZIL', 'REAL'),
#    ('JAPAN', 'YEN', 'CANADA', 'DOLLAR'),
#    ('JAPAN', 'YEN', 'EUROPE', 'EURO'),
#    ('KOREA', 'WON', 'USA', 'DOLLAR'),
#    ('KOREA', 'WON', 'VIETNAM', 'DONG'),
#    ('KOREA', 'WON', 'BRAZIL', 'REAL'),
#    ('KOREA', 'WON', 'CANADA', 'DOLLAR'),
#    ('KOREA', 'WON', 'EUROPE', 'EURO'),
#    ('KOREA', 'WON', 'JAPAN', 'YEN'),
#    ('USA', 'DOLLAR', 'VIETNAM', 'DONG'),
#    ('USA', 'DOLLAR', 'BRAZIL', 'REAL'),
#    ('USA', 'DOLLAR', 'EUROPE', 'EURO'),
#    ('USA', 'DOLLAR', 'JAPAN', 'YEN'),
#    ('USA', 'DOLLAR', 'KOREA', 'WON'),
#    ('VIETNAM', 'DONG', 'BRAZIL', 'REAL'),
#    ('VIETNAM', 'DONG', 'CANADA', 'DOLLAR'),
#    ('VIETNAM', 'DONG', 'EUROPE', 'EURO'),
#    ('VIETNAM', 'DONG', 'JAPAN', 'YEN'),
#    ('VIETNAM', 'DONG', 'KOREA', 'WON'),
#    ('VIETNAM', 'DONG', 'USA', 'DOLLAR')],
#   'section': 'currency'},
#  {'correct': [('HOUSTON', 'TEXAS', 'MIAMI', 'FLORIDA'),
#    ('DALLAS', 'TEXAS', 'MIAMI', 'FLORIDA'),
#    ('JACKSONVILLE', 'FLORIDA', 'HONOLULU', 'HAWAII'),
#    ('INDIANAPOLIS', 'INDIANA', 'SACRAMENTO', 'CALIFORNIA'),
#    ('INDIANAPOLIS', 'INDIANA', 'MIAMI', 'FLORIDA'),
#    ('AUSTIN', 'TEXAS', 'MIAMI', 'FLORIDA'),
#    ('AUSTIN', 'TEXAS', 'MINNEAPOLIS', 'MINNESOTA'),
#    ('DETROIT', 'MICHIGAN', 'FRESNO', 'CALIFORNIA'),
#    ('DETROIT', 'MICHIGAN', 'MIAMI', 'FLORIDA'),
#    ('DETROIT', 'MICHIGAN', 'ORLANDO', 'FLORIDA'),
#    ('LOUISVILLE', 'KENTUCKY', 'MIAMI', 'FLORIDA'),
#    ('MILWAUKEE', 'WISCONSIN', 'MIAMI', 'FLORIDA'),
#    ('PORTLAND', 'OREGON', 'MIAMI', 'FLORIDA'),
#    ('TUCSON', 'ARIZONA', 'MIAMI', 'FLORIDA'),
#    ('FRESNO', 'CALIFORNIA', 'MIAMI', 'FLORIDA'),
#    ('SACRAMENTO', 'CALIFORNIA', 'MIAMI', 'FLORIDA'),
#    ('MESA', 'ARIZONA', 'MIAMI', 'FLORIDA'),
#    ('OAKLAND', 'CALIFORNIA', 'TAMPA', 'FLORIDA'),
#    ('OAKLAND', 'CALIFORNIA', 'ORLANDO', 'FLORIDA'),
#    ('LEXINGTON', 'KENTUCKY', 'HOUSTON', 'TEXAS'),
#    ('LEXINGTON', 'KENTUCKY', 'AUSTIN', 'TEXAS'),
#    ('CHANDLER', 'ARIZONA', 'FREMONT', 'CALIFORNIA'),
#    ('IRVINE', 'CALIFORNIA', 'AUSTIN', 'TEXAS'),
#    ('IRVINE', 'CALIFORNIA', 'MIAMI', 'FLORIDA'),
#    ('SPOKANE', 'WASHINGTON', 'MIAMI', 'FLORIDA')],
#   'incorrect': [('CHICAGO', 'ILLINOIS', 'HOUSTON', 'TEXAS'),
#    ('CHICAGO', 'ILLINOIS', 'PHILADELPHIA', 'PENNSYLVANIA'),
#    ('CHICAGO', 'ILLINOIS', 'PHOENIX', 'ARIZONA'),
#    ('CHICAGO', 'ILLINOIS', 'DALLAS', 'TEXAS'),
#    ('CHICAGO', 'ILLINOIS', 'JACKSONVILLE', 'FLORIDA'),
#    ('CHICAGO', 'ILLINOIS', 'INDIANAPOLIS', 'INDIANA'),
#    ('CHICAGO', 'ILLINOIS', 'AUSTIN', 'TEXAS'),
#    ('CHICAGO', 'ILLINOIS', 'DETROIT', 'MICHIGAN'),
#    ('CHICAGO', 'ILLINOIS', 'MEMPHIS', 'TENNESSEE'),
#    ('CHICAGO', 'ILLINOIS', 'BOSTON', 'MASSACHUSETTS'),
#    ('CHICAGO', 'ILLINOIS', 'SEATTLE', 'WASHINGTON'),
#    ('CHICAGO', 'ILLINOIS', 'DENVER', 'COLORADO'),
#    ('CHICAGO', 'ILLINOIS', 'BALTIMORE', 'MARYLAND'),
#    ('CHICAGO', 'ILLINOIS', 'NASHVILLE', 'TENNESSEE'),
#    ('CHICAGO', 'ILLINOIS', 'LOUISVILLE', 'KENTUCKY'),
#    ('CHICAGO', 'ILLINOIS', 'MILWAUKEE', 'WISCONSIN'),
#    ('CHICAGO', 'ILLINOIS', 'PORTLAND', 'OREGON'),
#    ('CHICAGO', 'ILLINOIS', 'TUCSON', 'ARIZONA'),
#    ('CHICAGO', 'ILLINOIS', 'FRESNO', 'CALIFORNIA'),
#    ('CHICAGO', 'ILLINOIS', 'SACRAMENTO', 'CALIFORNIA'),
#    ('CHICAGO', 'ILLINOIS', 'MESA', 'ARIZONA'),
#    ('CHICAGO', 'ILLINOIS', 'ATLANTA', 'GEORGIA'),
#    ('CHICAGO', 'ILLINOIS', 'OMAHA', 'NEBRASKA'),
#    ('CHICAGO', 'ILLINOIS', 'MIAMI', 'FLORIDA'),
#    ('CHICAGO', 'ILLINOIS', 'TULSA', 'OKLAHOMA'),
#    ('CHICAGO', 'ILLINOIS', 'OAKLAND', 'CALIFORNIA'),
#    ('CHICAGO', 'ILLINOIS', 'CLEVELAND', 'OHIO'),
#    ('PHOENIX', 'ARIZONA', 'TULSA', 'OKLAHOMA'),
#    ('PHOENIX', 'ARIZONA', 'OAKLAND', 'CALIFORNIA'),
#    ('PHOENIX', 'ARIZONA', 'CLEVELAND', 'OHIO'),
#    ('PHOENIX', 'ARIZONA', 'MINNEAPOLIS', 'MINNESOTA'),
#    ('PHOENIX', 'ARIZONA', 'WICHITA', 'KANSAS'),
#    ('PHOENIX', 'ARIZONA', 'ARLINGTON', 'TEXAS'),
#    ('PHOENIX', 'ARIZONA', 'TAMPA', 'FLORIDA'),
#    ('PHOENIX', 'ARIZONA', 'ANAHEIM', 'CALIFORNIA'),
#    ('PHOENIX', 'ARIZONA', 'HONOLULU', 'HAWAII'),
#    ('PHOENIX', 'ARIZONA', 'PITTSBURGH', 'PENNSYLVANIA'),
#    ('PHOENIX', 'ARIZONA', 'LEXINGTON', 'KENTUCKY'),
#    ('PHOENIX', 'ARIZONA', 'CINCINNATI', 'OHIO'),
#    ('PHOENIX', 'ARIZONA', 'TOLEDO', 'OHIO'),
#    ('DALLAS', 'TEXAS', 'JACKSONVILLE', 'FLORIDA'),
#    ('DALLAS', 'TEXAS', 'INDIANAPOLIS', 'INDIANA'),
#    ('DALLAS', 'TEXAS', 'DETROIT', 'MICHIGAN'),
#    ('DALLAS', 'TEXAS', 'MEMPHIS', 'TENNESSEE'),
#    ('DALLAS', 'TEXAS', 'BOSTON', 'MASSACHUSETTS'),
#    ('DALLAS', 'TEXAS', 'SEATTLE', 'WASHINGTON'),
#    ('DALLAS', 'TEXAS', 'DENVER', 'COLORADO'),
#    ('DALLAS', 'TEXAS', 'BALTIMORE', 'MARYLAND'),
#    ('DALLAS', 'TEXAS', 'NASHVILLE', 'TENNESSEE'),
#    ('DALLAS', 'TEXAS', 'LOUISVILLE', 'KENTUCKY'),
#    ('DALLAS', 'TEXAS', 'MILWAUKEE', 'WISCONSIN'),
#    ('DALLAS', 'TEXAS', 'PORTLAND', 'OREGON'),
#    ('DALLAS', 'TEXAS', 'TUCSON', 'ARIZONA'),
#    ('DALLAS', 'TEXAS', 'FRESNO', 'CALIFORNIA'),
#    ('DALLAS', 'TEXAS', 'SACRAMENTO', 'CALIFORNIA'),
#    ('DALLAS', 'TEXAS', 'MESA', 'ARIZONA'),
#    ('DALLAS', 'TEXAS', 'ATLANTA', 'GEORGIA'),
#    ('DALLAS', 'TEXAS', 'OMAHA', 'NEBRASKA'),
#    ('DALLAS', 'TEXAS', 'TULSA', 'OKLAHOMA'),
#    ('DALLAS', 'TEXAS', 'OAKLAND', 'CALIFORNIA'),
#    ('DALLAS', 'TEXAS', 'CLEVELAND', 'OHIO'),
#    ('DALLAS', 'TEXAS', 'MINNEAPOLIS', 'MINNESOTA'),
#    ('DALLAS', 'TEXAS', 'WICHITA', 'KANSAS'),
#    ('DALLAS', 'TEXAS', 'TAMPA', 'FLORIDA'),
#    ('DALLAS', 'TEXAS', 'ANAHEIM', 'CALIFORNIA'),
#    ('DALLAS', 'TEXAS', 'HONOLULU', 'HAWAII'),
#    ('INDIANAPOLIS', 'INDIANA', 'DETROIT', 'MICHIGAN'),
#    ('INDIANAPOLIS', 'INDIANA', 'MEMPHIS', 'TENNESSEE'),
#    ('INDIANAPOLIS', 'INDIANA', 'BOSTON', 'MASSACHUSETTS'),
#    ('INDIANAPOLIS', 'INDIANA', 'SEATTLE', 'WASHINGTON'),
#    ('INDIANAPOLIS', 'INDIANA', 'DENVER', 'COLORADO'),
#    ('INDIANAPOLIS', 'INDIANA', 'BALTIMORE', 'MARYLAND'),
#    ('INDIANAPOLIS', 'INDIANA', 'NASHVILLE', 'TENNESSEE'),
#    ('INDIANAPOLIS', 'INDIANA', 'LOUISVILLE', 'KENTUCKY'),
#    ('INDIANAPOLIS', 'INDIANA', 'MILWAUKEE', 'WISCONSIN'),
#    ('INDIANAPOLIS', 'INDIANA', 'PORTLAND', 'OREGON'),
#    ('INDIANAPOLIS', 'INDIANA', 'TUCSON', 'ARIZONA'),
#    ('INDIANAPOLIS', 'INDIANA', 'FRESNO', 'CALIFORNIA'),
#    ('INDIANAPOLIS', 'INDIANA', 'MESA', 'ARIZONA'),
#    ('INDIANAPOLIS', 'INDIANA', 'ATLANTA', 'GEORGIA'),
#    ('INDIANAPOLIS', 'INDIANA', 'OMAHA', 'NEBRASKA'),
#    ('INDIANAPOLIS', 'INDIANA', 'TULSA', 'OKLAHOMA'),
#    ('INDIANAPOLIS', 'INDIANA', 'OAKLAND', 'CALIFORNIA'),
#    ('INDIANAPOLIS', 'INDIANA', 'CLEVELAND', 'OHIO'),
#    ('INDIANAPOLIS', 'INDIANA', 'MINNEAPOLIS', 'MINNESOTA'),
#    ('INDIANAPOLIS', 'INDIANA', 'WICHITA', 'KANSAS'),
#    ('INDIANAPOLIS', 'INDIANA', 'ARLINGTON', 'TEXAS'),
#    ('INDIANAPOLIS', 'INDIANA', 'TAMPA', 'FLORIDA'),
#    ('INDIANAPOLIS', 'INDIANA', 'ANAHEIM', 'CALIFORNIA'),
#    ('INDIANAPOLIS', 'INDIANA', 'HONOLULU', 'HAWAII'),
#    ('INDIANAPOLIS', 'INDIANA', 'PITTSBURGH', 'PENNSYLVANIA'),
#    ('INDIANAPOLIS', 'INDIANA', 'LEXINGTON', 'KENTUCKY'),
#    ('INDIANAPOLIS', 'INDIANA', 'CINCINNATI', 'OHIO'),
#    ('INDIANAPOLIS', 'INDIANA', 'TOLEDO', 'OHIO'),
#    ('INDIANAPOLIS', 'INDIANA', 'ORLANDO', 'FLORIDA'),
#    ('INDIANAPOLIS', 'INDIANA', 'CHANDLER', 'ARIZONA'),
#    ('AUSTIN', 'TEXAS', 'DETROIT', 'MICHIGAN'),
#    ('AUSTIN', 'TEXAS', 'MEMPHIS', 'TENNESSEE'),
#    ('AUSTIN', 'TEXAS', 'BOSTON', 'MASSACHUSETTS'),
#    ('AUSTIN', 'TEXAS', 'SEATTLE', 'WASHINGTON'),
#    ('AUSTIN', 'TEXAS', 'DENVER', 'COLORADO'),
#    ('AUSTIN', 'TEXAS', 'BALTIMORE', 'MARYLAND'),
#    ('AUSTIN', 'TEXAS', 'NASHVILLE', 'TENNESSEE'),
#    ('AUSTIN', 'TEXAS', 'LOUISVILLE', 'KENTUCKY'),
#    ('AUSTIN', 'TEXAS', 'MILWAUKEE', 'WISCONSIN'),
#    ('AUSTIN', 'TEXAS', 'PORTLAND', 'OREGON'),
#    ('AUSTIN', 'TEXAS', 'TUCSON', 'ARIZONA'),
#    ('AUSTIN', 'TEXAS', 'FRESNO', 'CALIFORNIA'),
#    ('AUSTIN', 'TEXAS', 'SACRAMENTO', 'CALIFORNIA'),
#    ('AUSTIN', 'TEXAS', 'MESA', 'ARIZONA'),
#    ('AUSTIN', 'TEXAS', 'ATLANTA', 'GEORGIA'),
#    ('AUSTIN', 'TEXAS', 'OMAHA', 'NEBRASKA'),
#    ('AUSTIN', 'TEXAS', 'TULSA', 'OKLAHOMA'),
#    ('AUSTIN', 'TEXAS', 'OAKLAND', 'CALIFORNIA'),
#    ('AUSTIN', 'TEXAS', 'CLEVELAND', 'OHIO'),
#    ('AUSTIN', 'TEXAS', 'WICHITA', 'KANSAS'),
#    ('AUSTIN', 'TEXAS', 'TAMPA', 'FLORIDA'),
#    ('AUSTIN', 'TEXAS', 'ANAHEIM', 'CALIFORNIA'),
#    ('AUSTIN', 'TEXAS', 'HONOLULU', 'HAWAII'),
#    ('AUSTIN', 'TEXAS', 'PITTSBURGH', 'PENNSYLVANIA'),
#    ('AUSTIN', 'TEXAS', 'LEXINGTON', 'KENTUCKY'),
#    ('AUSTIN', 'TEXAS', 'CINCINNATI', 'OHIO'),
#    ('AUSTIN', 'TEXAS', 'TOLEDO', 'OHIO'),
#    ('AUSTIN', 'TEXAS', 'ORLANDO', 'FLORIDA'),
#    ('AUSTIN', 'TEXAS', 'CHANDLER', 'ARIZONA'),
#    ('AUSTIN', 'TEXAS', 'MADISON', 'WISCONSIN'),
#    ('DETROIT', 'MICHIGAN', 'MEMPHIS', 'TENNESSEE'),
#    ('DETROIT', 'MICHIGAN', 'BOSTON', 'MASSACHUSETTS'),
#    ('DETROIT', 'MICHIGAN', 'SEATTLE', 'WASHINGTON'),
#    ('DETROIT', 'MICHIGAN', 'DENVER', 'COLORADO'),
#    ('DETROIT', 'MICHIGAN', 'BALTIMORE', 'MARYLAND'),
#    ('DETROIT', 'MICHIGAN', 'NASHVILLE', 'TENNESSEE'),
#    ('DETROIT', 'MICHIGAN', 'LOUISVILLE', 'KENTUCKY'),
#    ('DETROIT', 'MICHIGAN', 'MILWAUKEE', 'WISCONSIN'),
#    ('DETROIT', 'MICHIGAN', 'PORTLAND', 'OREGON'),
#    ('DETROIT', 'MICHIGAN', 'TUCSON', 'ARIZONA'),
#    ('DETROIT', 'MICHIGAN', 'SACRAMENTO', 'CALIFORNIA'),
#    ('DETROIT', 'MICHIGAN', 'MESA', 'ARIZONA'),
#    ('DETROIT', 'MICHIGAN', 'ATLANTA', 'GEORGIA'),
#    ('DETROIT', 'MICHIGAN', 'OMAHA', 'NEBRASKA'),
#    ('DETROIT', 'MICHIGAN', 'TULSA', 'OKLAHOMA'),
#    ('DETROIT', 'MICHIGAN', 'OAKLAND', 'CALIFORNIA'),
#    ('DETROIT', 'MICHIGAN', 'CLEVELAND', 'OHIO'),
#    ('DETROIT', 'MICHIGAN', 'MINNEAPOLIS', 'MINNESOTA'),
#    ('DETROIT', 'MICHIGAN', 'WICHITA', 'KANSAS'),
#    ('DETROIT', 'MICHIGAN', 'ARLINGTON', 'TEXAS'),
#    ('DETROIT', 'MICHIGAN', 'TAMPA', 'FLORIDA'),
#    ('DETROIT', 'MICHIGAN', 'ANAHEIM', 'CALIFORNIA'),
#    ('DETROIT', 'MICHIGAN', 'HONOLULU', 'HAWAII'),
#    ('DETROIT', 'MICHIGAN', 'PITTSBURGH', 'PENNSYLVANIA'),
#    ('DETROIT', 'MICHIGAN', 'LEXINGTON', 'KENTUCKY'),
#    ('DETROIT', 'MICHIGAN', 'CINCINNATI', 'OHIO'),
#    ('DETROIT', 'MICHIGAN', 'TOLEDO', 'OHIO'),
#    ('DETROIT', 'MICHIGAN', 'CHANDLER', 'ARIZONA'),
#    ('DETROIT', 'MICHIGAN', 'MADISON', 'WISCONSIN'),
#    ('MEMPHIS', 'TENNESSEE', 'BOSTON', 'MASSACHUSETTS'),
#    ('MEMPHIS', 'TENNESSEE', 'SEATTLE', 'WASHINGTON'),
#    ('MEMPHIS', 'TENNESSEE', 'DENVER', 'COLORADO'),
#    ('MEMPHIS', 'TENNESSEE', 'BALTIMORE', 'MARYLAND'),
#    ('MEMPHIS', 'TENNESSEE', 'LOUISVILLE', 'KENTUCKY'),
#    ('MEMPHIS', 'TENNESSEE', 'MILWAUKEE', 'WISCONSIN'),
#    ('MEMPHIS', 'TENNESSEE', 'PORTLAND', 'OREGON'),
#    ('MEMPHIS', 'TENNESSEE', 'TUCSON', 'ARIZONA'),
#    ('MEMPHIS', 'TENNESSEE', 'FRESNO', 'CALIFORNIA'),
#    ('MEMPHIS', 'TENNESSEE', 'SACRAMENTO', 'CALIFORNIA'),
#    ('MEMPHIS', 'TENNESSEE', 'MESA', 'ARIZONA'),
#    ('MEMPHIS', 'TENNESSEE', 'ATLANTA', 'GEORGIA'),
#    ('MEMPHIS', 'TENNESSEE', 'OMAHA', 'NEBRASKA'),
#    ('MEMPHIS', 'TENNESSEE', 'MIAMI', 'FLORIDA'),
#    ('MEMPHIS', 'TENNESSEE', 'TULSA', 'OKLAHOMA'),
#    ('MEMPHIS', 'TENNESSEE', 'OAKLAND', 'CALIFORNIA'),
#    ('MEMPHIS', 'TENNESSEE', 'CLEVELAND', 'OHIO'),
#    ('MEMPHIS', 'TENNESSEE', 'MINNEAPOLIS', 'MINNESOTA'),
#    ('MEMPHIS', 'TENNESSEE', 'WICHITA', 'KANSAS'),
#    ('MEMPHIS', 'TENNESSEE', 'ARLINGTON', 'TEXAS'),
#    ('MEMPHIS', 'TENNESSEE', 'TAMPA', 'FLORIDA'),
#    ('MEMPHIS', 'TENNESSEE', 'ANAHEIM', 'CALIFORNIA'),
#    ('MEMPHIS', 'TENNESSEE', 'HONOLULU', 'HAWAII'),
#    ('PHOENIX', 'ARIZONA', 'HONOLULU', 'HAWAII'),
#    ('PHOENIX', 'ARIZONA', 'PITTSBURGH', 'PENNSYLVANIA'),
#    ('PHOENIX', 'ARIZONA', 'LEXINGTON', 'KENTUCKY'),
#    ('PHOENIX', 'ARIZONA', 'CINCINNATI', 'OHIO'),
#    ('PHOENIX', 'ARIZONA', 'TOLEDO', 'OHIO'),
#    ('DALLAS', 'TEXAS', 'JACKSONVILLE', 'FLORIDA'),
#    ('DALLAS', 'TEXAS', 'INDIANAPOLIS', 'INDIANA'),
#    ('DALLAS', 'TEXAS', 'DETROIT', 'MICHIGAN'),
#    ('DALLAS', 'TEXAS', 'MEMPHIS', 'TENNESSEE'),
#    ('DALLAS', 'TEXAS', 'BOSTON', 'MASSACHUSETTS'),
#    ('DALLAS', 'TEXAS', 'SEATTLE', 'WASHINGTON'),
#    ('DALLAS', 'TEXAS', 'DENVER', 'COLORADO'),
#    ('DALLAS', 'TEXAS', 'BALTIMORE', 'MARYLAND'),
#    ('DALLAS', 'TEXAS', 'NASHVILLE', 'TENNESSEE'),
#    ('DALLAS', 'TEXAS', 'LOUISVILLE', 'KENTUCKY'),
#    ('DALLAS', 'TEXAS', 'MILWAUKEE', 'WISCONSIN'),
#    ('DALLAS', 'TEXAS', 'PORTLAND', 'OREGON'),
#    ('DALLAS', 'TEXAS', 'TUCSON', 'ARIZONA'),
#    ('DALLAS', 'TEXAS', 'FRESNO', 'CALIFORNIA'),
#    ('DALLAS', 'TEXAS', 'SACRAMENTO', 'CALIFORNIA'),
#    ('DALLAS', 'TEXAS', 'MESA', 'ARIZONA'),
#    ('DALLAS', 'TEXAS', 'ATLANTA', 'GEORGIA'),
#    ('DALLAS', 'TEXAS', 'OMAHA', 'NEBRASKA'),
#    ('DALLAS', 'TEXAS', 'TULSA', 'OKLAHOMA'),
#    ('DALLAS', 'TEXAS', 'OAKLAND', 'CALIFORNIA'),
#    ('DALLAS', 'TEXAS', 'CLEVELAND', 'OHIO'),
#    ('DALLAS', 'TEXAS', 'MINNEAPOLIS', 'MINNESOTA'),
#    ('DALLAS', 'TEXAS', 'WICHITA', 'KANSAS'),
#    ('DALLAS', 'TEXAS', 'TAMPA', 'FLORIDA'),
#    ('DALLAS', 'TEXAS', 'ANAHEIM', 'CALIFORNIA'),
#    ('DALLAS', 'TEXAS', 'HONOLULU', 'HAWAII'),
#    ('DALLAS', 'TEXAS', 'PITTSBURGH', 'PENNSYLVANIA'),
#    ('DALLAS', 'TEXAS', 'LEXINGTON', 'KENTUCKY'),
#    ('DALLAS', 'TEXAS', 'CINCINNATI', 'OHIO'),
#    ('DALLAS', 'TEXAS', 'TOLEDO', 'OHIO'),
#    ('DALLAS', 'TEXAS', 'ORLANDO', 'FLORIDA'),
#    ('JACKSONVILLE', 'FLORIDA', 'INDIANAPOLIS', 'INDIANA'),
#    ('JACKSONVILLE', 'FLORIDA', 'AUSTIN', 'TEXAS'),
#    ('JACKSONVILLE', 'FLORIDA', 'DETROIT', 'MICHIGAN'),
#    ('INDIANAPOLIS', 'INDIANA', 'MILWAUKEE', 'WISCONSIN'),
#    ('INDIANAPOLIS', 'INDIANA', 'PORTLAND', 'OREGON'),
#    ('INDIANAPOLIS', 'INDIANA', 'TUCSON', 'ARIZONA'),
#    ('INDIANAPOLIS', 'INDIANA', 'FRESNO', 'CALIFORNIA'),
#    ('INDIANAPOLIS', 'INDIANA', 'MESA', 'ARIZONA'),
#    ('INDIANAPOLIS', 'INDIANA', 'ATLANTA', 'GEORGIA'),
#    ('INDIANAPOLIS', 'INDIANA', 'OMAHA', 'NEBRASKA'),
#    ('INDIANAPOLIS', 'INDIANA', 'TULSA', 'OKLAHOMA'),
#    ('INDIANAPOLIS', 'INDIANA', 'OAKLAND', 'CALIFORNIA'),
#    ('INDIANAPOLIS', 'INDIANA', 'CLEVELAND', 'OHIO'),
#    ('INDIANAPOLIS', 'INDIANA', 'MINNEAPOLIS', 'MINNESOTA'),
#    ('INDIANAPOLIS', 'INDIANA', 'WICHITA', 'KANSAS'),
#    ('INDIANAPOLIS', 'INDIANA', 'ARLINGTON', 'TEXAS'),
#    ('INDIANAPOLIS', 'INDIANA', 'TAMPA', 'FLORIDA'),
#    ('INDIANAPOLIS', 'INDIANA', 'ANAHEIM', 'CALIFORNIA'),
#    ('INDIANAPOLIS', 'INDIANA', 'HONOLULU', 'HAWAII'),
#    ('INDIANAPOLIS', 'INDIANA', 'PITTSBURGH', 'PENNSYLVANIA'),
#    ('INDIANAPOLIS', 'INDIANA', 'LEXINGTON', 'KENTUCKY'),
#    ('INDIANAPOLIS', 'INDIANA', 'CINCINNATI', 'OHIO'),
#    ('INDIANAPOLIS', 'INDIANA', 'TOLEDO', 'OHIO'),
#    ('INDIANAPOLIS', 'INDIANA', 'ORLANDO', 'FLORIDA'),
#    ('INDIANAPOLIS', 'INDIANA', 'CHANDLER', 'ARIZONA'),
#    ('AUSTIN', 'TEXAS', 'DETROIT', 'MICHIGAN'),
#    ('AUSTIN', 'TEXAS', 'MEMPHIS', 'TENNESSEE'),
#    ('AUSTIN', 'TEXAS', 'BOSTON', 'MASSACHUSETTS'),
#    ('AUSTIN', 'TEXAS', 'SEATTLE', 'WASHINGTON'),
#    ('AUSTIN', 'TEXAS', 'DENVER', 'COLORADO'),
#    ('AUSTIN', 'TEXAS', 'BALTIMORE', 'MARYLAND'),
#    ('AUSTIN', 'TEXAS', 'NASHVILLE', 'TENNESSEE'),
#    ('AUSTIN', 'TEXAS', 'LOUISVILLE', 'KENTUCKY'),
#    ('AUSTIN', 'TEXAS', 'MILWAUKEE', 'WISCONSIN'),
#    ('AUSTIN', 'TEXAS', 'PORTLAND', 'OREGON'),
#    ('AUSTIN', 'TEXAS', 'TUCSON', 'ARIZONA'),
#    ('AUSTIN', 'TEXAS', 'FRESNO', 'CALIFORNIA'),
#    ('AUSTIN', 'TEXAS', 'SACRAMENTO', 'CALIFORNIA'),
#    ('AUSTIN', 'TEXAS', 'MESA', 'ARIZONA'),
#    ('AUSTIN', 'TEXAS', 'ATLANTA', 'GEORGIA'),
#    ('AUSTIN', 'TEXAS', 'OMAHA', 'NEBRASKA'),
#    ('AUSTIN', 'TEXAS', 'TULSA', 'OKLAHOMA'),
#    ('AUSTIN', 'TEXAS', 'OAKLAND', 'CALIFORNIA'),
#    ('AUSTIN', 'TEXAS', 'CLEVELAND', 'OHIO'),
#    ('AUSTIN', 'TEXAS', 'WICHITA', 'KANSAS'),
#    ('AUSTIN', 'TEXAS', 'TAMPA', 'FLORIDA'),
#    ('AUSTIN', 'TEXAS', 'ANAHEIM', 'CALIFORNIA'),
#    ('AUSTIN', 'TEXAS', 'HONOLULU', 'HAWAII'),
#    ('AUSTIN', 'TEXAS', 'PITTSBURGH', 'PENNSYLVANIA'),
#    ('AUSTIN', 'TEXAS', 'LEXINGTON', 'KENTUCKY'),
#    ('AUSTIN', 'TEXAS', 'CINCINNATI', 'OHIO'),
#    ('AUSTIN', 'TEXAS', 'TOLEDO', 'OHIO'),
#    ('AUSTIN', 'TEXAS', 'ORLANDO', 'FLORIDA'),
#    ('AUSTIN', 'TEXAS', 'CHANDLER', 'ARIZONA'),
#    ('AUSTIN', 'TEXAS', 'MADISON', 'WISCONSIN'),
#    ('DETROIT', 'MICHIGAN', 'MEMPHIS', 'TENNESSEE'),
#    ('DETROIT', 'MICHIGAN', 'BOSTON', 'MASSACHUSETTS'),
#    ('DETROIT', 'MICHIGAN', 'SEATTLE', 'WASHINGTON'),
#    ('DETROIT', 'MICHIGAN', 'DENVER', 'COLORADO'),
#    ('DETROIT', 'MICHIGAN', 'BALTIMORE', 'MARYLAND'),
#    ('DETROIT', 'MICHIGAN', 'NASHVILLE', 'TENNESSEE'),
#    ('DETROIT', 'MICHIGAN', 'LOUISVILLE', 'KENTUCKY'),
#    ('DETROIT', 'MICHIGAN', 'MILWAUKEE', 'WISCONSIN'),
#    ('DETROIT', 'MICHIGAN', 'PORTLAND', 'OREGON'),
#    ('DETROIT', 'MICHIGAN', 'TUCSON', 'ARIZONA'),
#    ('DETROIT', 'MICHIGAN', 'SACRAMENTO', 'CALIFORNIA'),
#    ('DETROIT', 'MICHIGAN', 'MESA', 'ARIZONA'),
#    ('DETROIT', 'MICHIGAN', 'ATLANTA', 'GEORGIA'),
#    ('DETROIT', 'MICHIGAN', 'OMAHA', 'NEBRASKA'),
#    ('DETROIT', 'MICHIGAN', 'TULSA', 'OKLAHOMA'),
#    ('DETROIT', 'MICHIGAN', 'OAKLAND', 'CALIFORNIA'),
#    ('DETROIT', 'MICHIGAN', 'CLEVELAND', 'OHIO'),
#    ('DETROIT', 'MICHIGAN', 'MINNEAPOLIS', 'MINNESOTA'),
#    ('DETROIT', 'MICHIGAN', 'WICHITA', 'KANSAS'),
#    ('DETROIT', 'MICHIGAN', 'ARLINGTON', 'TEXAS'),
#    ('DETROIT', 'MICHIGAN', 'TAMPA', 'FLORIDA'),
#    ('DETROIT', 'MICHIGAN', 'ANAHEIM', 'CALIFORNIA'),
#    ('DETROIT', 'MICHIGAN', 'HONOLULU', 'HAWAII'),
#    ('DETROIT', 'MICHIGAN', 'PITTSBURGH', 'PENNSYLVANIA'),
#    ('DETROIT', 'MICHIGAN', 'LEXINGTON', 'KENTUCKY'),
#    ('DETROIT', 'MICHIGAN', 'CINCINNATI', 'OHIO'),
#    ('DETROIT', 'MICHIGAN', 'TOLEDO', 'OHIO'),
#    ('DETROIT', 'MICHIGAN', 'CHANDLER', 'ARIZONA'),
#    ('DETROIT', 'MICHIGAN', 'MADISON', 'WISCONSIN'),
#    ('MEMPHIS', 'TENNESSEE', 'BOSTON', 'MASSACHUSETTS'),
#    ('MEMPHIS', 'TENNESSEE', 'SEATTLE', 'WASHINGTON'),
#    ('MEMPHIS', 'TENNESSEE', 'DENVER', 'COLORADO'),
#    ('MEMPHIS', 'TENNESSEE', 'BALTIMORE', 'MARYLAND'),
#    ('MEMPHIS', 'TENNESSEE', 'LOUISVILLE', 'KENTUCKY'),
#    ('MEMPHIS', 'TENNESSEE', 'MILWAUKEE', 'WISCONSIN'),
#    ('MEMPHIS', 'TENNESSEE', 'PORTLAND', 'OREGON'),
#    ('MEMPHIS', 'TENNESSEE', 'TUCSON', 'ARIZONA'),
#    ('MEMPHIS', 'TENNESSEE', 'FRESNO', 'CALIFORNIA'),
#    ('MEMPHIS', 'TENNESSEE', 'SACRAMENTO', 'CALIFORNIA'),
#    ('MEMPHIS', 'TENNESSEE', 'MESA', 'ARIZONA'),
#    ('MEMPHIS', 'TENNESSEE', 'ATLANTA', 'GEORGIA'),
#    ('MEMPHIS', 'TENNESSEE', 'OMAHA', 'NEBRASKA'),
#    ('MEMPHIS', 'TENNESSEE', 'MIAMI', 'FLORIDA'),
#    ('MEMPHIS', 'TENNESSEE', 'TULSA', 'OKLAHOMA'),
#    ('MEMPHIS', 'TENNESSEE', 'OAKLAND', 'CALIFORNIA'),
#    ('MEMPHIS', 'TENNESSEE', 'CLEVELAND', 'OHIO'),
#    ('MEMPHIS', 'TENNESSEE', 'MINNEAPOLIS', 'MINNESOTA'),
#    ('MEMPHIS', 'TENNESSEE', 'WICHITA', 'KANSAS'),
#    ('MEMPHIS', 'TENNESSEE', 'ARLINGTON', 'TEXAS'),
#    ('MEMPHIS', 'TENNESSEE', 'TAMPA', 'FLORIDA'),
#    ('MEMPHIS', 'TENNESSEE', 'ANAHEIM', 'CALIFORNIA'),
#    ('MEMPHIS', 'TENNESSEE', 'HONOLULU', 'HAWAII'),
#    ('MEMPHIS', 'TENNESSEE', 'PITTSBURGH', 'PENNSYLVANIA'),
#    ('MEMPHIS', 'TENNESSEE', 'LEXINGTON', 'KENTUCKY'),
#    ('MEMPHIS', 'TENNESSEE', 'CINCINNATI', 'OHIO'),
#    ('MEMPHIS', 'TENNESSEE', 'TOLEDO', 'OHIO'),
#    ('MEMPHIS', 'TENNESSEE', 'ORLANDO', 'FLORIDA'),
#    ('MEMPHIS', 'TENNESSEE', 'CHANDLER', 'ARIZONA'),
#    ('MEMPHIS', 'TENNESSEE', 'MADISON', 'WISCONSIN'),
#    ('BOSTON', 'MASSACHUSETTS', 'SEATTLE', 'WASHINGTON'),
#    ('SEATTLE', 'WASHINGTON', 'FRESNO', 'CALIFORNIA'),
#    ('SEATTLE', 'WASHINGTON', 'SACRAMENTO', 'CALIFORNIA'),
#    ('SEATTLE', 'WASHINGTON', 'MESA', 'ARIZONA'),
#    ('SEATTLE', 'WASHINGTON', 'ATLANTA', 'GEORGIA'),
#    ('SEATTLE', 'WASHINGTON', 'OMAHA', 'NEBRASKA'),
#    ('SEATTLE', 'WASHINGTON', 'MIAMI', 'FLORIDA'),
#    ('SEATTLE', 'WASHINGTON', 'TULSA', 'OKLAHOMA'),
#    ('SEATTLE', 'WASHINGTON', 'OAKLAND', 'CALIFORNIA'),
#    ('SEATTLE', 'WASHINGTON', 'CLEVELAND', 'OHIO'),
#    ('SEATTLE', 'WASHINGTON', 'MINNEAPOLIS', 'MINNESOTA'),
#    ('SEATTLE', 'WASHINGTON', 'WICHITA', 'KANSAS'),
#    ('SEATTLE', 'WASHINGTON', 'ARLINGTON', 'TEXAS'),
#    ('SEATTLE', 'WASHINGTON', 'TAMPA', 'FLORIDA'),
#    ('SEATTLE', 'WASHINGTON', 'ANAHEIM', 'CALIFORNIA'),
#    ('SEATTLE', 'WASHINGTON', 'HONOLULU', 'HAWAII'),
#    ('SEATTLE', 'WASHINGTON', 'PITTSBURGH', 'PENNSYLVANIA'),
#    ('SEATTLE', 'WASHINGTON', 'LEXINGTON', 'KENTUCKY'),
#    ('SEATTLE', 'WASHINGTON', 'CINCINNATI', 'OHIO'),
#    ('SEATTLE', 'WASHINGTON', 'TOLEDO', 'OHIO'),
#    ('SEATTLE', 'WASHINGTON', 'ORLANDO', 'FLORIDA'),
#    ('SEATTLE', 'WASHINGTON', 'CHANDLER', 'ARIZONA'),
#    ('SEATTLE', 'WASHINGTON', 'MADISON', 'WISCONSIN'),
#    ('DENVER', 'COLORADO', 'BALTIMORE', 'MARYLAND'),
#    ('DENVER', 'COLORADO', 'NASHVILLE', 'TENNESSEE'),
#    ('DENVER', 'COLORADO', 'LOUISVILLE', 'KENTUCKY'),
#    ('DENVER', 'COLORADO', 'MILWAUKEE', 'WISCONSIN'),
#    ('DENVER', 'COLORADO', 'PORTLAND', 'OREGON'),
#    ('DENVER', 'COLORADO', 'TUCSON', 'ARIZONA'),
#    ('DENVER', 'COLORADO', 'FRESNO', 'CALIFORNIA'),
#    ('DENVER', 'COLORADO', 'SACRAMENTO', 'CALIFORNIA'),
#    ('DENVER', 'COLORADO', 'MESA', 'ARIZONA'),
#    ('DENVER', 'COLORADO', 'ATLANTA', 'GEORGIA'),
#    ('DENVER', 'COLORADO', 'OMAHA', 'NEBRASKA'),
#    ('DENVER', 'COLORADO', 'MIAMI', 'FLORIDA'),
#    ('DENVER', 'COLORADO', 'TULSA', 'OKLAHOMA'),
#    ('DENVER', 'COLORADO', 'OAKLAND', 'CALIFORNIA'),
#    ('DENVER', 'COLORADO', 'CLEVELAND', 'OHIO'),
#    ('DENVER', 'COLORADO', 'MINNEAPOLIS', 'MINNESOTA'),
#    ('DENVER', 'COLORADO', 'WICHITA', 'KANSAS'),
#    ('DENVER', 'COLORADO', 'ARLINGTON', 'TEXAS'),
#    ('DENVER', 'COLORADO', 'TAMPA', 'FLORIDA'),
#    ('DENVER', 'COLORADO', 'ANAHEIM', 'CALIFORNIA'),
#    ('DENVER', 'COLORADO', 'HONOLULU', 'HAWAII'),
#    ('DENVER', 'COLORADO', 'PITTSBURGH', 'PENNSYLVANIA'),
#    ('DENVER', 'COLORADO', 'LEXINGTON', 'KENTUCKY'),
#    ('DENVER', 'COLORADO', 'CINCINNATI', 'OHIO'),
#    ('DENVER', 'COLORADO', 'TOLEDO', 'OHIO'),
#    ('DENVER', 'COLORADO', 'ORLANDO', 'FLORIDA'),
#    ('DENVER', 'COLORADO', 'CHANDLER', 'ARIZONA'),
#    ('DENVER', 'COLORADO', 'MADISON', 'WISCONSIN'),
#    ('DENVER', 'COLORADO', 'RENO', 'NEVADA'),
#    ('BALTIMORE', 'MARYLAND', 'NASHVILLE', 'TENNESSEE'),
#    ('BALTIMORE', 'MARYLAND', 'LOUISVILLE', 'KENTUCKY'),
#    ('BALTIMORE', 'MARYLAND', 'MILWAUKEE', 'WISCONSIN'),
#    ('BALTIMORE', 'MARYLAND', 'PORTLAND', 'OREGON'),
#    ('BALTIMORE', 'MARYLAND', 'TUCSON', 'ARIZONA'),
#    ('BALTIMORE', 'MARYLAND', 'FRESNO', 'CALIFORNIA'),
#    ('BALTIMORE', 'MARYLAND', 'SACRAMENTO', 'CALIFORNIA'),
#    ('BALTIMORE', 'MARYLAND', 'MESA', 'ARIZONA'),
#    ('BALTIMORE', 'MARYLAND', 'ATLANTA', 'GEORGIA'),
#    ('BALTIMORE', 'MARYLAND', 'OMAHA', 'NEBRASKA'),
#    ('BALTIMORE', 'MARYLAND', 'MIAMI', 'FLORIDA'),
#    ('BALTIMORE', 'MARYLAND', 'TULSA', 'OKLAHOMA'),
#    ('BALTIMORE', 'MARYLAND', 'OAKLAND', 'CALIFORNIA'),
#    ('BALTIMORE', 'MARYLAND', 'CLEVELAND', 'OHIO'),
#    ('BALTIMORE', 'MARYLAND', 'MINNEAPOLIS', 'MINNESOTA'),
#    ('BALTIMORE', 'MARYLAND', 'WICHITA', 'KANSAS'),
#    ('BALTIMORE', 'MARYLAND', 'ARLINGTON', 'TEXAS'),
#    ('BALTIMORE', 'MARYLAND', 'TAMPA', 'FLORIDA'),
#    ('BALTIMORE', 'MARYLAND', 'ANAHEIM', 'CALIFORNIA'),
#    ('BALTIMORE', 'MARYLAND', 'HONOLULU', 'HAWAII'),
#    ('BALTIMORE', 'MARYLAND', 'PITTSBURGH', 'PENNSYLVANIA'),
#    ('BALTIMORE', 'MARYLAND', 'LEXINGTON', 'KENTUCKY'),
#    ('BALTIMORE', 'MARYLAND', 'CINCINNATI', 'OHIO'),
#    ('BALTIMORE', 'MARYLAND', 'TOLEDO', 'OHIO'),
#    ('BALTIMORE', 'MARYLAND', 'ORLANDO', 'FLORIDA'),
#    ('BALTIMORE', 'MARYLAND', 'CHANDLER', 'ARIZONA'),
#    ('BALTIMORE', 'MARYLAND', 'MADISON', 'WISCONSIN'),
#    ('BALTIMORE', 'MARYLAND', 'RENO', 'NEVADA'),
#    ('BALTIMORE', 'MARYLAND', 'SCOTTSDALE', 'ARIZONA'),
#    ('NASHVILLE', 'TENNESSEE', 'LOUISVILLE', 'KENTUCKY'),
#    ...],
#   'section': 'total'}]

# %% [markdown]
# The total accuracy is 25.8%, which shows that the accuracy is not very high for most of the questions. However we observe that it has obtained 58.2% accuracy for family-related words and decent scores for gram3-comparative(44.9%)/gram5-present-participle(53.8%)/gram7-past-tense (42.7%) and gram9-plural-verbs(38.1%). From these we can interpret that the tweets are more related to these topics. The below similarity tests also shows that our word2vec model has preserved the relationship between the words.

# %%
print(model.most_similar(positive=['woman', 'actress'], negative=['man'], topn=1))
print(model.most_similar(positive=['dad', 'family'], negative=['man'], topn=2))
# Out:
# [('actor', 0.8064113259315491)]
# [('grandma', 0.721605658531189), ('mom', 0.7162371873855591)]

# %%
print("model.similarity('dad', 'mom'): %f" %model.similarity('dad', 'mom'))
print("model.similarity('happy','homework'): %f" %model.similarity('happy','homework'))
# Out:
# model.similarity('dad', 'mom'): 0.957098
# model.similarity('happy','homework'): 0.069131

# %% [markdown]
# # w2v for classification
#
# As compared to the tweet tokenizer, the regular expression tokenizer results in better performance in classification task. Therefore I build a new w2v model with regular expression tokernized texts.

# %%
w2v_data = data["text"]
tokenizer = RegexpTokenizer(r'\w+')
w2v_data = list(map(tokenizer.tokenize,w2v_data))

def tolower(sentence):
    sentence = list(map(str.lower, sentence))
    return sentence

w2v_data = list(map(tolower,w2v_data))

# %%
# import modules & set up logging
import gensim, logging
from gensim.models import word2vec
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
sentences = w2v_data

# train word2vec on the tweets, 100 dimensions
model = gensim.models.Word2Vec(sentences, min_count=1,size=100)
# create w2v dictionary
w2v = {w: vec for w, vec in zip(model.wv.index2word, model.wv.syn0)}
# Out:
# 2018-04-15 14:52:52,411 : INFO : collecting all words and their counts
# 2018-04-15 14:52:52,417 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-04-15 14:52:52,492 : INFO : PROGRESS: at sentence #10000, processed 132890 words, keeping 17982 word types
# 2018-04-15 14:52:52,558 : INFO : PROGRESS: at sentence #20000, processed 279320 words, keeping 29291 word types
# 2018-04-15 14:52:52,639 : INFO : PROGRESS: at sentence #30000, processed 419620 words, keeping 39877 word types
# 2018-04-15 14:52:52,734 : INFO : PROGRESS: at sentence #40000, processed 561328 words, keeping 50131 word types
# 2018-04-15 14:52:52,823 : INFO : PROGRESS: at sentence #50000, processed 701022 words, keeping 59887 word types
# 2018-04-15 14:52:52,937 : INFO : PROGRESS: at sentence #60000, processed 841149 words, keeping 69750 word types
# 2018-04-15 14:52:53,092 : INFO : PROGRESS: at sentence #70000, processed 982608 words, keeping 79330 word types
# 2018-04-15 14:52:53,176 : INFO : PROGRESS: at sentence #80000, processed 1123228 words, keeping 88166 word types
# 2018-04-15 14:52:53,253 : INFO : PROGRESS: at sentence #90000, processed 1261230 words, keeping 97094 word types
# 2018-04-15 14:53:07,532 : INFO : PROGRESS: at sentence #1470000, processed 20562521 words, keeping 662578 word types
# 2018-04-15 14:53:07,650 : INFO : PROGRESS: at sentence #1480000, processed 20706381 words, keeping 664164 word types
# 2018-04-15 14:53:07,732 : INFO : PROGRESS: at sentence #1490000, processed 20849978 words, keeping 666028 word types
# 2018-04-15 14:53:07,811 : INFO : PROGRESS: at sentence #1500000, processed 20982163 words, keeping 667928 word types
# 2018-04-15 14:53:07,899 : INFO : PROGRESS: at sentence #1510000, processed 21114549 words, keeping 669637 word types
# 2018-04-15 14:53:07,996 : INFO : PROGRESS: at sentence #1520000, processed 21259647 words, keeping 671471 word types
# 2018-04-15 14:53:08,096 : INFO : PROGRESS: at sentence #1530000, processed 21394091 words, keeping 674404 word types
# 2018-04-15 14:53:08,183 : INFO : PROGRESS: at sentence #1540000, processed 21532218 words, keeping 676023 word types
# 2018-04-15 14:53:08,274 : INFO : PROGRESS: at sentence #1550000, processed 21672376 words, keeping 678082 word types
# 2018-04-15 14:53:08,365 : INFO : PROGRESS: at sentence #1560000, processed 21808623 words, keeping 679945 word types
# 2018-04-15 14:53:08,477 : INFO : PROGRESS: at sentence #1570000, processed 21948446 words, keeping 681595 word types
# 2018-04-15 14:53:08,604 : INFO : collected 683263 word types from a corpus of 22065210 raw words and 1578627 sentences
# 2018-04-15 14:53:08,607 : INFO : Loading a fresh vocabulary
# 2018-04-15 14:53:10,723 : INFO : min_count=1 retains 683263 unique words (100% of original 683263, drops 0)
# 2018-04-15 14:53:10,724 : INFO : min_count=1 leaves 22065210 word corpus (100% of original 22065210, drops 0)
# 2018-04-15 14:53:12,827 : INFO : deleting the raw counts dictionary of 683263 items
# 2018-04-15 14:53:12,869 : INFO : sample=0.001 downsamples 53 most-common words
# 2018-04-15 14:53:12,870 : INFO : downsampling leaves estimated 17641987 word corpus (80.0% of prior 22065210)
# 2018-04-15 14:53:15,556 : INFO : estimated required memory for 683263 words and 100 dimensions: 888241900 bytes
# 2018-04-15 14:53:15,558 : INFO : resetting layer weights
# 2018-04-15 14:53:24,968 : INFO : training model with 3 workers on 683263 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2018-04-15 14:53:26,007 : INFO : EPOCH 1 - PROGRESS: at 1.03% examples, 184519 words/s, in_qsize 6, out_qsize 1
# 2018-04-15 14:53:27,008 : INFO : EPOCH 1 - PROGRESS: at 4.15% examples, 364974 words/s, in_qsize 5, out_qsize 0
# 2018-04-15 14:53:28,011 : INFO : EPOCH 1 - PROGRESS: at 7.36% examples, 434257 words/s, in_qsize 5, out_qsize 0
# 2018-04-15 14:53:29,016 : INFO : EPOCH 1 - PROGRESS: at 10.47% examples, 464944 words/s, in_qsize 5, out_qsize 0
# 2018-04-15 14:53:30,034 : INFO : EPOCH 1 - PROGRESS: at 13.53% examples, 479080 words/s, in_qsize 6, out_qsize 0
# 2018-04-15 14:53:31,045 : INFO : EPOCH 1 - PROGRESS: at 16.45% examples, 486245 words/s, in_qsize 5, out_qsize 0
# 2018-04-15 14:53:32,049 : INFO : EPOCH 1 - PROGRESS: at 18.17% examples, 461185 words/s, in_qsize 5, out_qsize 0
# 2018-04-15 14:53:33,064 : INFO : EPOCH 1 - PROGRESS: at 20.18% examples, 447822 words/s, in_qsize 4, out_qsize 1
# 2018-04-15 14:53:34,090 : INFO : EPOCH 1 - PROGRESS: at 22.32% examples, 439577 words/s, in_qsize 5, out_qsize 0
# 2018-04-15 14
words/s, in_qsize 5, out_qsize 0
# 2018-04-15 14:55:52,339 : INFO : EPOCH 5 - PROGRESS: at 62.04% examples, 517964 words/s, in_qsize 5, out_qsize 0
# 2018-04-15 14:55:53,347 : INFO : EPOCH 5 - PROGRESS: at 65.44% examples, 521750 words/s, in_qsize 6, out_qsize 0
# 2018-04-15 14:55:54,356 : INFO : EPOCH 5 - PROGRESS: at 68.83% examples, 524280 words/s, in_qsize 5, out_qsize 0
# 2018-04-15 14:55:55,363 : INFO : EPOCH 5 - PROGRESS: at 71.75% examples, 523799 words/s, in_qsize 5, out_qsize 0
# 2018-04-15 14:55:56,377 : INFO : EPOCH 5 - PROGRESS: at 75.05% examples, 525778 words/s, in_qsize 5, out_qsize 0
# 2018-04-15 14:55:57,379 : INFO : EPOCH 5 - PROGRESS: at 78.03% examples, 525859 words/s, in_qsize 5, out_qsize 0
# 2018-04-15 14:55:58,381 : INFO : EPOCH 5 - PROGRESS: at 80.91% examples, 525278 words/s, in_qsize 5, out_qsize 0
# 2018-04-15 14:55:59,394 : INFO : EPOCH 5 - PROGRESS: at 84.06% examples, 525809 words/s, in_qsize 5, out_qsize 0
# 2018-04-15 14:56:00,399 : INFO : EPOCH 5 - PROGRESS: at 87.19% examples, 526717 words/s, in_qsize 5, out_qsize 0
# 2018-04-15 14:56:01,407 : INFO : EPOCH 5 - PROGRESS: at 90.44% examples, 527702 words/s, in_qsize 5, out_qsize 0
# 2018-04-15 14:56:02,410 : INFO : EPOCH 5 - PROGRESS: at 93.94% examples, 530218 words/s, in_qsize 5, out_qsize 0
# 2018-04-15 14:56:03,426 : INFO : EPOCH 5 - PROGRESS: at 97.26% examples, 531500 words/s, in_qsize 4, out_qsize 1
# 2018-04-15 14:56:04,242 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-15 14:56:04,245 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-15 14:56:04,251 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-15 14:56:04,252 : INFO : EPOCH - 5 : training on 22065210 raw words (17641957 effective words) took 33.1s, 532645 effective words/s
# 2018-04-15 14:56:04,253 : INFO : training on a 110326050 raw words (88214375 effective words) took 159.3s, 553835 effective words/s

# %% [markdown]
# # Create training set and testing set

# %%
X_data = data["text"]
y_data = data["label"]
from sklearn.cross_validation import StratifiedShuffleSplit
for train, test in StratifiedShuffleSplit(y_data, n_iter=5, test_size = 0.25):
        X_train, X_test = X_data[train], X_data[test]
        y_train, y_test = y_data[train], y_data[test]

# %% [markdown]
# # Other classification models

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(stop_words = "english",lowercase=True)
O_X_train = vectorizer.fit_transform(X_train)
O_X_test = vectorizer.transform(X_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,auc
from sklearn.cross_validation import cross_val_score
import scikitplot as skplt
import matplotlib.pyplot as plt

#define a function for performance metrics
def model_eval(model,X_train,y_train, X_test,y_test):
    print (model)
    model.fit(X_train,y_train)
    pred = model.predict(X_test)
    print ("prediciton Accuracy : %f" % accuracy_score(y_test, pred))
    print ("Confusion_matrix : ")
    print (confusion_matrix(y_test,pred))
    print ("classification report : ")
    print (classification_report(y_test, pred, labels=['0', '1']))
        
    if not str(model)[:3] == "SGD":
        pred_proba = model.predict_proba(X_test)
        pred_proba_c1 = pred_proba[:,1]
        print ("AUC Score : %f" % sklearn.metrics.roc_auc_score(y_test, pred_proba_c1))

# %%
#all models
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegressionCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import SGDClassifier 

NB = MultinomialNB()
LRcv = LogisticRegressionCV(solver="liblinear",penalty = "l1",cv = 5,random_state = 42)  
RF = RandomForestClassifier(n_estimators =100, max_features = "sqrt",bootstrap = True, 
                            oob_score=True,verbose=0,class_weight = "balanced",
                            random_state=42,max_depth = 40)
GBC = GradientBoostingClassifier(learning_rate=0.05, n_estimators=260,max_depth=35, 
                                 min_samples_leaf =3, min_samples_split =150, 
                                 max_features=40, subsample=0.7, random_state=42)
SGD = SGDClassifier(loss="hinge", penalty="l2", alpha=0.0001,           
                    l1_ratio=0.15, fit_intercept=True, random_state = 42,
                    shuffle=True, learning_rate="optimal", 
                    n_iter= np.ceil(10**6 / O_X_train.shape[0]))

# %%
model_eval(NB, O_X_train, y_train, O_X_test,y_test)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)
# prediciton Accuracy : 0.754309
# Confusion_matrix :
# [[466857 124475]
#  [166416 426223]]
# classification report :
#              precision    recall  f1-score   support
#
#           0       0.74      0.79      0.76    591332
#           1       0.77      0.72      0.75    592639
#
# avg / total       0.76      0.75      0.75   1183971
#
# AUC Score : 0.838127

# %%
model_eval(LRcv, O_X_train, y_train, O_X_test,y_test)
# Out:
# LogisticRegressionCV(Cs=10, class_weight=None, cv=5, dual=False,
#            fit_intercept=True, intercept_scaling=1.0, max_iter=100,
#            multi_class='ovr', n_jobs=1, penalty='l1', random_state=42,
#            refit=True, scoring=None, solver='liblinear', tol=0.0001,
#            verbose=0)
# prediciton Accuracy : 0.770769
# Confusion_matrix :
# [[444898 146434]
#  [124969 467670]]
# classification report :
#              precision    recall  f1-score   support
#
#           0       0.78      0.75      0.77    591332
#           1       0.76      0.79      0.78    592639
#
# avg / total       0.77      0.77      0.77   1183971
#
# AUC Score : 0.850202

# %%
model_eval(RF, O_X_train, y_train, O_X_test,y_test)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight='balanced',
#             criterion='gini', max_depth=40, max_features='sqrt',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=100, n_jobs=1, oob_score=True, random_state=42,
#             verbose=0, warm_start=False)
# prediciton Accuracy : 0.739393
# Confusion_matrix :
# [[413675 177657]
#  [130894 461745]]
# classification report :
#              precision    recall  f1-score   support
#
#           0       0.76      0.70      0.73    591332
#           1       0.72      0.78      0.75    592639
#
# avg / total       0.74      0.74      0.74   1183971
#
# AUC Score : 0.812129

# %%
model_eval(GBC, O_X_train, y_train, O_X_test,y_test)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.05, loss='deviance', max_depth=35,
#               max_features=40, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=3, min_samples_split=150,
#               min_weight_fraction_leaf=0.0, n_estimators=260,
#               presort='auto', random_state=42, subsample=0.7, verbose=0,
#               warm_start=False)
# prediciton Accuracy : 0.705119
# Confusion_matrix :
# [[391555 199777]
#  [149353 443286]]
# classification report :
#              precision    recall  f1-score   support
#
#           0       0.72      0.66      0.69    591332
#           1       0.69      0.75      0.72    592639
#
# avg / total       0.71      0.71      0.70   1183971
#
# AUC Score : 0.773016

# %%
model_eval(SGD, O_X_train, y_train, O_X_test,y_test)
# Out:
# SGDClassifier(alpha=0.0001, average=False, class_weight=None, epsilon=0.1,
#        eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', max_iter=None, n_iter=3.0,
#        n_jobs=1, penalty='l2', power_t=0.5, random_state=42, shuffle=True,
#        tol=None, verbose=0, warm_start=False)
# prediciton Accuracy : 0.754985
# Confusion_matrix :
# [[408647 182685]
#  [107406 485233]]
# classification report :
#              precision    recall  f1-score   support
#
#           0       0.79      0.69      0.74    591332
#           1       0.73      0.82      0.77    592639
#
# avg / total       0.76      0.75      0.75   1183971

# %% [markdown]
# We observe that logistic regression obtain the best result as represented by the accuracy scores and other performance metrics.

# %% [markdown]
# # classify using word2vec result
#
# https://github.com/nadbordrozd/blog_stuff/blob/master/classification_w2v/benchmarking_python3.ipynb
# implement an embedding vectorizer - a counterpart of CountVectorizer and TfidfVectorizer - that is given a word -> vector mapping and vectorizes texts by taking the mean of all the vectors corresponding to individual words.

# %%
w2v_train = X_train
w2v_train = list(map(tokenizer.tokenize,w2v_train))
w2v_train = list(map(tolower,w2v_train))

w2v_test = X_test
w2v_test = list(map(tokenizer.tokenize,w2v_test))
w2v_test = list(map(tolower,w2v_test))

# %%
from collections import Counter, defaultdict
# a tf-idf version
class TfidfEmbeddingVectorizer(object):
    def __init__(self, word2vec):
        self.word2vec = word2vec
        self.word2weight = None
        if len(word2vec)>0:
            self.dim=100
        else:
            self.dim=0
        
    def fit(self, X, y):
        tfidf = TfidfVectorizer(analyzer=lambda x: x)
        tfidf.fit(X)
        # if a word was never seen - it must be at least as infrequent
        # as any of the known words - so the default idf is the max of 
        # known idf's
        max_idf = max(tfidf.idf_)
        self.word2weight = defaultdict(
            lambda: max_idf, 
            [(w, tfidf.idf_[i]) for w, i in tfidf.vocabulary_.items()])
    
        return self
    
    def transform(self, X):
        return np.array([
                np.mean([self.word2vec[w] * self.word2weight[w]
                         for w in words if w in self.word2vec] or
                        [np.zeros(self.dim)], axis=0)
                for words in X
            ])

# %%
LRcv_classifier_w2v = LogisticRegressionCV(solver="liblinear",
                                           penalty = "l1",
                                           cv = 5,random_state = 42)

# %%
from sklearn.pipeline import Pipeline
LRcv_w2v = Pipeline([("word2vec vectorizer", TfidfEmbeddingVectorizer(w2v)), 
                        ("LRcv", LRcv_classifier_w2v)])

# %%
model_eval(LRcv_w2v, w2v_train, y_train, w2v_test,y_test)
# Out:
# Pipeline(memory=None,
#      steps=[('word2vec vectorizer', <__main__.TfidfEmbeddingVectorizer object at 0x2c241eb38>), ('LRcv', LogisticRegressionCV(Cs=10, class_weight='balanced', cv=5, dual=False,
#            fit_intercept=True, intercept_scaling=1.0, max_iter=100,
#            multi_class='ovr', n_jobs=1, penalty='l1', random_state=42,
#            refit=True, scoring=None, solver='liblinear', tol=0.0001,
#            verbose=0))])
# prediciton Accuracy : 0.753804
# Confusion_matrix :
# [[445699 145633]
#  [145856 446783]]
# classification report :
#              precision    recall  f1-score   support
#
#           0       0.75      0.75      0.75    591332
#           1       0.75      0.75      0.75    592639
#
# avg / total       0.75      0.75      0.75   1183971
#
# AUC Score : 0.832537

# %% [markdown]
# # Use CNN from keras

# %%
import keras
from keras import utils
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Dense, Input, GlobalMaxPooling1D
from keras.layers import Conv1D, MaxPooling1D, Embedding
from keras.models import Model

tokenizer = Tokenizer()
tokenizer.fit_on_texts(w2v_data)
sequences = tokenizer.texts_to_sequences(w2v_data)

word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))

newdata = pad_sequences(sequences)
# Out:
# Found 683263 unique tokens.

# %%
labels = keras.utils.to_categorical(np.asarray(y_data))
print('Shape of data tensor:', newdata.shape)
print('Shape of label tensor:', labels.shape)
# Out:
# Shape of data tensor: (1578627, 303)
# Shape of label tensor: (1578627, 2)

# %%
# split the data into a training set and a validation set
indices = np.arange(newdata.shape[0])
np.random.shuffle(indices)
newdata = newdata[indices]
labels = labels[indices]
nb_validation_samples = int(0.25 * newdata.shape[0])

x_train = newdata[:-nb_validation_samples]
y_train = labels[:-nb_validation_samples]
x_val = newdata[-nb_validation_samples:]
y_val = labels[-nb_validation_samples:]

# %% [markdown]
# ## Create the embedding matrix
# Create the embedding matrix by using the w2v trained previously.

# %%
print('Found %s word vectors.' % len(w2v))
# Out:
# Found 683263 word vectors.

# %%
EMBEDDING_DIM = 100
MAX_SEQUENCE_LENGTH = min(1000, newdata.shape[1])

embedding_matrix = np.zeros((len(word_index) + 1, EMBEDDING_DIM))
for word, i in word_index.items():
    embedding_vector = w2v.get(word)
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector

# %%
embedding_layer = Embedding(len(word_index) + 1,
                            EMBEDDING_DIM,
                            weights=[embedding_matrix],
                            trainable=False)

# %% [markdown]
# ## Training a 1D CNN

# %%
sequence_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype='int32')
embedded_sequences = embedding_layer(sequence_input)
x = Conv1D(128, 5, activation='relu')(embedded_sequences)
x = MaxPooling1D(5)(x)
x = Conv1D(128, 5, activation='relu')(x)
x = MaxPooling1D(5)(x)
x = Conv1D(128, 5, activation='relu')(x)
x = GlobalMaxPooling1D()(x)
x = Dense(128, activation='relu')(x)
preds = Dense(labels.shape[1], activation='softmax')(x)
# Out:
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead

# %%
model = Model(sequence_input, preds)
model.compile(loss='categorical_crossentropy',optimizer='rmsprop',metrics=['acc'])

model.fit(x_train, y_train,batch_size=128,epochs=2,validation_data=(x_val, y_val))
# Out:
# Train on 1183971 samples, validate on 394656 samples
# Epoch 1/2
#  180608/1183971 [===>..........................] - ETA: 47:09 - loss: 0.5567 - acc: 0.7117

# %% [markdown]
# The algorithm stop running probably due to the large data size. We try to use a smaller dataset by randoming choosing 10% of the data.

# %%
small_samples = int(0.1* newdata.shape[0])
x_small = newdata[-small_samples:]
y_small = labels[-small_samples:]

nb_validation_samples = int(0.25 * x_small.shape[0])
x_train = x_small[:-nb_validation_samples]
y_train = y_small[:-nb_validation_samples]
x_val = x_small[-nb_validation_samples:]
y_val = y_small[-nb_validation_samples:]
print(x_train.shape)
# Out:
# (118397, 303)

# %%
model = Model(sequence_input, preds)
model.compile(loss='categorical_crossentropy',optimizer='rmsprop',metrics=['acc'])

model.fit(x_train, y_train,batch_size=128,epochs=2,validation_data=(x_val, y_val))
# Out:
# Train on 118397 samples, validate on 39465 samples
# Epoch 1/2
# 118397/118397 [==============================] - 363s 3ms/step - loss: 0.5878 - acc: 0.6855 - val_loss: 0.5667 - val_acc: 0.7069
# Epoch 2/2
# 118397/118397 [==============================] - 398s 3ms/step - loss: 0.5538 - acc: 0.7129 - val_loss: 0.5681 - val_acc: 0.7044

# %% [markdown]
# ## Use pretrained embedding
# from Glove: glove.twitter.27B.100 dimensions

# %%
# %cd /Users/Allen/Documents/NLP/package/glove.twitter.27B
encoding="utf-8"
glove_twitter_path = "glove.twitter.27B.100d.txt"

with open(glove_twitter_path, "rb") as lines:
    wvec = {line.split()[0].decode(encoding): np.array(line.split()[1:],dtype=np.float32)
               for line in lines}
import struct 
glove_twitter = {}
all_words = set(w for words in w2v_data for w in words)
with open(glove_twitter_path, "rb") as infile:
    for line in infile:
        parts = line.split()
        word = parts[0].decode(encoding)
        if (word in all_words):
            nums=np.array(parts[1:], dtype=np.float32)
            glove_twitter[word] = nums
# Out:
# /Users/Allen/Documents/NLP/package/glove.twitter.27B

# %% [markdown]
# Train on the same subset of data, manually run for 6 epochs

# %%
embedding_matrix = np.zeros((len(word_index) + 1, EMBEDDING_DIM))
for word, i in word_index.items():
    embedding_vector = glove_twitter.get(word)
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector
from keras.layers import Embedding        
embedding_layer = Embedding(len(word_index) + 1,
                            EMBEDDING_DIM,
                            weights=[embedding_matrix],
                            trainable=False)

sequence_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype='int32')
embedded_sequences = embedding_layer(sequence_input)
x = Conv1D(128, 5, activation='relu')(embedded_sequences)
x = MaxPooling1D(5)(x)
x = Conv1D(128, 5, activation='relu')(x)
x = MaxPooling1D(5)(x)
x = Conv1D(128, 5, activation='relu')(x)
x = GlobalMaxPooling1D()(x)
x = Dense(128, activation='relu')(x)
preds = Dense(labels.shape[1], activation='softmax')(x)

# %%
model = Model(sequence_input, preds)
model.compile(loss='categorical_crossentropy',optimizer='rmsprop',metrics=['acc'])
model.fit(x_train, y_train, batch_size=128, epochs=2,validation_data=(x_val, y_val))
# Out:
# Train on 118397 samples, validate on 39465 samples
# Epoch 1/2
# 118397/118397 [==============================] - 368s 3ms/step - loss: 0.5884 - acc: 0.6861 - val_loss: 0.5672 - val_acc: 0.7008
# Epoch 2/2
# 118397/118397 [==============================] - 392s 3ms/step - loss: 0.5525 - acc: 0.7137 - val_loss: 0.5588 - val_acc: 0.7077

# %%
model.fit(x_train, y_train, batch_size=128, epochs=2,validation_data=(x_val, y_val))
# Out:
# Train on 118397 samples, validate on 39465 samples
# Epoch 1/2
# 118397/118397 [==============================] - 366s 3ms/step - loss: 0.5276 - acc: 0.7317 - val_loss: 0.5754 - val_acc: 0.7001
# Epoch 2/2
# 118397/118397 [==============================] - 395s 3ms/step - loss: 0.5039 - acc: 0.7462 - val_loss: 0.5694 - val_acc: 0.7076

# %%
model.fit(x_train, y_train, batch_size=128, epochs=2,validation_data=(x_val, y_val))
# Out:
# Train on 118397 samples, validate on 39465 samples
# Epoch 1/2
# 118397/118397 [==============================] - 370s 3ms/step - loss: 0.4801 - acc: 0.7613 - val_loss: 0.5863 - val_acc: 0.7001
# Epoch 2/2
# 118397/118397 [==============================] - 394s 3ms/step - loss: 0.4575 - acc: 0.7732 - val_loss: 0.6121 - val_acc: 0.7013

# %% [markdown]
# # Reference
# - traditional classification methods by word embedding
# http://nadbordrozd.github.io/blog/2016/05/20/text-classification-with-word2vec/
# https://github.com/nadbordrozd/blog_stuff/blob/master/classification_w2v/benchmarking_python3.ipynb
#
# - keras CNN
# https://blog.keras.io/using-pre-trained-word-embeddings-in-a-keras-model.html
# https://github.com/keras-team/keras/blob/master/examples/pretrained_word_embeddings.py
